# %% [markdown]
# Katherine Kairis, kak275@pitt.edu, 10/12/2017

# %%
from bs4 import BeautifulSoup
import glob
import re
import nltk

# %%
transcripts = glob.glob('data/VOICE/VOICE2.0XML/XML/*.xml')
del transcripts[0]

# %%
#Create two dictionaries: one containing information about the participants, and one containing the conversations
participants = {}
conversations = {}

# %% [markdown]
# # Getting info about the participants
# The participant_info function extracts information about the participants and stores it in the "participants" dictionary. The keys of the dictionary are the participants' ID numbers. The values are sub-dictionaries that include the participant's role, age, sex, and occupation (if listed). The sub-dictionaries also include the participants' L1s, which are stored in lists (since some participants have multiple L1s).

# %%
def participant_info(contents):
    
    #Get all of the participants in the given conversation
    people = contents.find('listPerson', {'type': 'identified'}).findAll('person')
    
    for p in people:
        #info is a subdirector that contains a single participant's information. It will be 
        info = {}
        info['role'] = p['role']
        info['age'] = p.age.get_text()
        info['sex'] = p.sex.get_text()
        
        #In some cases, the occupation isn't listed. If it is included, get the text of the occupation field.
        #If it isn't included, "None" will be stored as the occupation, since p.occupation would return "None."
        try:
            info['occupation'] = p.occupation.get_text()
        except AttributeError:
            info['occupation'] = p.occupation
        
        #Get a list of the languages that the participant speaks. Iterate through the list, and add them to the
        #dictionary according to the speaker's level (ie. L1).
        languages = p.findAll('langKnown')
        for l in languages:
            level = l['level']
            language = l['tag']
        
            if level in info:
                info[level].append(language)
            else:
                info[level] = [language]
    
        #Get the participant's ID number, and make it a key in the participants dictionary. The value will be
        #the info dictionary
        name = p['xml:id']
        participants[name] = info

# %% [markdown]
# # Getting lines of the conversation from the file
# The conversation_lines function gets each line from the current conversation. The lines are stored as lists in the "conversations" dictionary, whose keys are the names of the XML files. For now, I decided to keep the lines in their XML format; there are a lot of annotations in the XML format that could be useful later on, such as the speaker, pauses, and intonation markings. Converting the XML lines into text/getting rid of the tags is simple, so I could change this later on.

# %%
def conversation_lines(file, contents):
    file_name = file.split("/")[-1]
    text_body = contents.body
    xml_lines = text_body.findAll('u')
    conversations[file_name] = xml_lines

# %% [markdown]
# # Processing the XML files
# This section iterates through all of the files (except for corpus-header.xml) in the VOICE1.0XML/XML directory. It calls conversation_lines and participant_info to extract some important parts of the data from the corpus.

# %%
for t in transcripts:
    file = open(t, 'r')
    text = file.read()
    xml_contents = BeautifulSoup(text, 'xml')
    conversation_lines(t, xml_contents)
    participant_info(xml_contents)

# %%
conversations['EDcon496.xml'][0]
# Out:
# <u who="#EDcon496_S1" xml:id="EDcon496_u_1"> e<c type="lengthening"/>r leads so <pause/> ma<c type="lengthening"/>n i'm still stuck on lead du<c type="lengthening"/>de <pause dur="PT3S"/></u>

# %%
participants['EDcon250_S2']
# Out:
# {'L1': ['ger-AT', 'eng-US'],
#  'age': '25-34',
#  'occupation': None,
#  'role': 'participant',
#  'sex': 'female'}

# %%
#Get native English speakers
native_speakers = []

#There are multiple ways that English is listed as an L1 ("eng", "eng-US", "eng-CA", "eng-GB", "eng-GY", "eng-AU", etc)
#I used a regular expression to find all of these instances
r = re.compile("eng.*")

for person in participants:
    
    #returns a list of all languages that contain "eng.*" The length of this list should be 1 or 0. If it's 1, the
    #participant has English listed as an L1.
    english = list(filter(r.match, participants[person]['L1']))
    
    if len(english) != 0:
        #print(person, ':', participants[person])
        native_speakers.append(person)

# %%
participant = native_speakers[0]
languages = participants[participant]['L1']

# %%
english_dialects = {}
for p in native_speakers:
    languages = participants[p]['L1']
    for l in languages:
        if 'eng' not in l:
            continue
        #print(l)
        
        if l not in english_dialects:
            english_dialects[l] = 1
        else:
            english_dialects[l] += 1

# %%
english_dialects
# Out:
# {'eng': 8,
#  'eng-AU': 3,
#  'eng-CA': 6,
#  'eng-GB': 39,
#  'eng-GY': 1,
#  'eng-IE': 3,
#  'eng-MT': 7,
#  'eng-US': 20}

# %%
bilinguals = []
L1_counts = {}
#participants[native_speakers[0]]
for p in participants:
    #print(participants[p]['L1'])
    languages = participants[p]['L1']
    if len(languages) > 1:
        bilinguals.append(p)
        if p in native_speakers:
            if 'eng' not in L1_counts:
                L1_counts['eng'] = 1
            else:
                L1_counts['eng'] += 1
        continue
    
    
    for l in languages:
        L1 = l.split("-")[0]
        if L1 not in L1_counts:
            L1_counts[L1] = 1
        else:
            L1_counts[L1] += 1
        #print(l.split("-")[0])

# %%
len(bilinguals)
# Out:
# 44

# %%
for p in bilinguals:
    print(participants[p]['L1'])
# Out:
# ['ger-AT', 'eng-US']
# ['eng-GY', 'dut-NL']
# ['fre-FR', 'eng']
# ['mlt-MT', 'eng-MT']
# ['mlt-MT', 'eng-MT']
# ['mlt-MT', 'eng-MT']
# ['mlt-MT', 'ger-AT']
# ['ger-AT', 'eng-US']
# ['ukr-UA', 'rus']
# ['ger-DE', 'ind-ID']
# ['ger-AT', 'eng-US']
# ['eng', 'heb', 'dut']
# ['slo-SK', 'ger']
# ['eng-CA', 'chi-CN']
# ['eng-CA', 'chi-CN']
# ['fre-CH', 'ger-CH']
# ['dut-NL', 'eng']
# ['eng-GB', 'spa-ES']
# ['fre-CH', 'ger-CH']
# ['eng-GB', 'spa-ES']
# ['eng-GB', 'spa-ES']
# ['eng-GB', 'spa-ES']
# ['fre-CH', 'ger-CH']
# ['eng-GB', 'spa-ES']
# ['eng-GB', 'spa-ES']
# ['fre-CH', 'ger-CH']
# ['eng-GB', 'spa-ES']
# ['fre-CH', 'ger-CH']
# ['eng-GB', 'spa-ES']
# ['mlt-MT', 'eng-MT']
# ['cat-ES', 'spa-ES']
# ['mlt-MT', 'eng-MT']
# ['mlt-MT', 'eng-MT']
# ['mlt-MT', 'eng-MT']
# ['spa-ES', 'cat-ES']
# ['dut', 'ger-AT']
# ['spa-ES', 'cat']
# ['por-PT', 'ger-AT']
# ['por-PT', 'ger-AT']
# ['dut', 'ger-AT']
# ['ger', 'ita']
# ['ger-AT', 'pol-PL']
# ['ara-PS', 'ger-AT']
# ['per-IR', 'eng-US']

# %%
L1_counts
# Out:
# {'alb': 11,
#  'ara': 4,
#  'arm': 6,
#  'bos': 5,
#  'bul': 13,
#  'cat': 6,
#  'chi': 7,
#  'cze': 18,
#  'dan': 35,
#  'dut': 72,
#  'eng': 87,
#  'est': 8,
#  'fin': 51,
#  'fre': 63,
#  'ger': 303,
#  'gre': 14,
#  'hin': 4,
#  'hun': 13,
#  'ice': 3,
#  'ind': 2,
#  'ita': 54,
#  'jpn': 5,
#  'kaz': 2,
#  'kir': 2,
#  'kor': 14,
#  'lav': 19,
#  'lit': 9,
#  'mac': 14,
#  'mlt': 22,
#  'nor': 34,
#  'per': 2,
#  'pol': 35,
#  'por': 21,
#  'rum': 30,
#  'rus': 22,
#  'scc': 24,
#  'scr': 13,
#  'slo': 29,
#  'slv': 16,
#  'spa': 72,
#  'swe': 16,
#  'tgl': 1,
#  'tur': 15,
#  'ukr': 4,
#  'und': 37,
#  'urd': 2,
#  'vie': 1,
#  'yor': 1}

# %%
modified_conversations = {}
lines = {}

for file in conversations:
    conv_lines = {}
    
    c = conversations[file]
    
    for l in c:
        participant = l['who'].replace("#", "")
        line_id = l['xml:id']
        text = l.get_text()
        tokens = nltk.word_tokenize(text)
        
        if participant in native_speakers:
            continue
            
        if participant not in participants:
            #print(participant)
            continue
        
        elif len(text) == 0:
            continue
    
        elif l.foreign != None:     #returns the line if has "foreign" tag; None if it doesn't contain the tag
            #print(l.foreign.get_text())   #text of line  
            #print(l.foreign['xml:lang'])  #language used
            #print(l)                      #line (in XML format)
            continue
        
        elif l.unclear != None:     #returns the line if has "unclear" tag; None if it doesn't contain the tag
            #    print(l)
            continue
    
        elif l.reading_aloud != None:
            continue
            #print(l)
        
        elif l.reading != None :
            continue
            #print(l)
        
        else:
            key = (line_id, participant)
            #conv_lines[key] = text
            conv_lines[key] = tokens
    
    modified_conversations[file] = conv_lines

# %%
#%pprint
#modified_conversations['EDcon4.xml']
#modified_conversations['EDsed364.xml']
#modified_conversations['EDsed362.xml']

# %%
##Processing Part of speech tagged corpus

# %%
transcripts = glob.glob('data/VOICE/VOICEPOSXML2.0/XML/*.xml')
del transcripts[0]

# %%
tagged_conversations = {}
def xml_conversation_lines(file, contents):
    file_name = file.split("/")[-1]
    tagged_conversations[file_name] = contents

# %%
for t in transcripts:
    file = open(t, 'r')
    text = file.read()
    xml_contents = BeautifulSoup(text, 'xml')
    #conversation_lines(t, xml_contents)
    #participant_info(xml_contents)
    xml_conversation_lines(t, xml_contents)

# %%
utterances = xml_contents.body.findAll('u')

for u in utterances[:5]:
    participant = u['who'].replace("#", "")
    line_id = u['xml:id']
    
    key = (participant, line_id)
    print(key)
    
    tags = u.findAll('w')
   
    for t in tags:
        word = t.get_text()
        tag = t['ana'].replace("#", "")
        tu = (word, tag)
        print('\t', tu)
# Out:
# ('PRwgd537_S10', 'PRwgd537_u_1')
# 	 ('er', 'UHfUH')
# 	 ('so', 'DMfDM')
# 	 ('c-', 'XXfXX')
# 	 ('c-', 'XXfXX')
# 	 ('can', 'MDfMD')
# 	 ('we', 'PPfPP')
# 	 ('prove', 'VVfVV')
# 	 ('that', 'INfIN')
# 	 ('if', 'INfIN')
# 	 ('er', 'UHfUH')
# 	 ('three', 'CDfCD')
# 	 ('form', 'NNfNN')
# 	 ('omega', 'NNfNN')
# 	 ('alpha', 'NNfNN')
# 	 ('define', 'VVPfVVP')
# 	 ('er', 'UHfUH')
# 	 ('this', 'DTfDT')
# 	 ('er', 'UHfUH')
# 	 ('distribution', 'NNfNN')
# 	 ('s_h', 'SYMfSYM')
# 	 ('_0', 'PAfPA')
# 	 ('and', 'CCfCC')
# 	 ('satisfies', 'VVZfVVZ')
# 	 ('this', 'DTfDT')
# 	 ('condition', 'NNfNN')
# 	 ('so', 'DMfDM')
# 	 ('in', 'INfIN')
# 	 ('fact', 'NNfNN')
# 	 ('er', 'UHfUH')
# 	 ('we', 'PPfPP')
# 	 ('have', 'VHPfVHP')
# 	 ('definition', 'NNfNN')
# 	 ('that', 'INfIN')
# 	 ('_0', 'PAfPA')
# 	 ('you', 'PPfPP')
# 	 ('say', 'VVPfVVP')
# 	 ('that', 'INfIN')
# ('PRwgd537_S11', 'PRwgd537_u_2')
# 	 ('yeah', 'REfRE')
# ('PRwgd537_S10', 'PRwgd537_u_3')
# 	 ('er', 'UHfUH')
# 	 ('three', 'CDfCD')
# 	 ('er', 'UHfUH')
# 	 ('_0', 'PAfPA')
# 	 ('okay', 'REfRE')
# 	 ('triple', 'NNfNN')
# 	 ('_1', 'PAfPA')
# 	 ('er', 'UHfUH')
# 	 ('triple', 'NNfNN')
# 	 ('er', 'UHfUH')
# 	 ('_0', 'PAfPA')
# 	 ('say', 'VVfVV')
# 	 ('er', 'UHfUH')
# 	 ('rho', 'NNfNN')
# 	 ('one', 'CDfCD')
# 	 ('rho', 'NNfNN')
# 	 ('two', 'CDfCD')
# 	 ('_0', 'PAfPA')
# 	 ('rho', 'NNfNN')
# 	 ('three', 'CDfCD')
# 	 ('_0', 'PAfPA')
# ('PRwgd537_S11', 'PRwgd537_u_4')
# 	 ('yeah', 'REfRE')
# ('PRwgd537_S10', 'PRwgd537_u_5')
# 	 ('er', 'UHfUH')
# 	 ('of', 'INfIN')
# 	 ('er', 'UHfUH')
# 	 ('two', 'CDfCD')
# 	 ('forms', 'NNSfNNS')
# 	 ('_1', 'PAfPA')
# 	 ('er', 'UHfUH')
# 	 ('on', 'INfIN')
# 	 ('_0', 'PAfPA')
# 	 ('er', 'UHfUH')
# 	 ('on', 'INfIN')
# 	 ('s_h', 'SYMfSYM')
# 	 ('are', 'VBPfVBP')
# 	 ('er', 'UHfUH')
# 	 ('of', 'INfIN')
# 	 ('p_quaternionic', 'PVCfJJ')
# 	 ('type', 'NNfNN')
# 	 ('_0', 'PAfPA')

# %%
pos_tagged = {}
for conv in tagged_conversations:
    conv_lines = {}
    
    for line in tagged_conversations[conv].body.findAll('u'):
        utterance = []
   
        participant = line['who'].replace("#", "")
        line_id = line['xml:id']
        
        key = (participant, line_id)
        
        tags = line.findAll('w')
        #print(tags)
   
        for t in tags:
            ##print(t)
            word = t.get_text()
            #tag = t['ana'].replace("#", "")
            #print(tag)
            #pair = (word, tag)
            ##print('\t', tu)
            utterance.append((word, tag))
        
        conv_lines[key] = utterance

    print(conv)
    pos_tagged[conv] = conv_lines
# Out:
# EDcon250.xml
# EDcon4.xml
# EDcon496.xml
# EDcon521.xml
# EDint328.xml
# EDint330.xml
# EDint331.xml
# EDint604.xml
# EDint605.xml
# EDsed251.xml
# EDsed301.xml
# EDsed31.xml
# EDsed362.xml
# EDsed363.xml
# EDsed364.xml
# EDsve421.xml
# EDsve422.xml
# EDsve423.xml
# EDsve451.xml
# EDsve452.xml
# EDwgd241.xml
# EDwgd305.xml
# EDwgd497.xml
# EDwgd5.xml
# EDwgd6.xml
# EDwsd15.xml
# EDwsd242.xml
# EDwsd302.xml
# EDwsd303.xml
# EDwsd304.xml
# EDwsd306.xml
# EDwsd464.xml
# EDwsd499.xml
# EDwsd590.xml
# EDwsd9.xml
# LEcon227.xml
# LEcon228.xml
# LEcon229.xml
# LEcon329.xml
# LEcon351.xml
# LEcon352.xml
# LEcon353.xml
# LEcon405.xml
# LEcon417.xml
# LEcon418.xml
# LEcon420.xml
# LEcon545.xml
# LEcon547.xml
# LEcon548.xml
# LEcon560.xml
# LEcon562.xml
# LEcon565.xml
# LEcon566.xml
# LEcon573.xml
# LEcon575.xml
# LEcon8.xml
# LEint551.xml
# LEint552.xml
# LEint553.xml
# LEint554.xml
# LEint555.xml
# PBcon594.xml
# PBmtg269.xml
# PBmtg27.xml
# PBmtg280.xml
# PBmtg3.xml
# PBmtg300.xml
# PBmtg414.xml
# PBmtg462.xml
# PBmtg463.xml
# PBpan10.xml
# PBpan25.xml
# PBpan28.xml
# PBpan581.xml
# PBqas410.xml
# PBqas411.xml
# PBqas412.xml
# PBqas523.xml
# PBsve426.xml
# PBsve430.xml
# PBsve434.xml
# PBsve435.xml
# PBsve436.xml
# PBsve437.xml
# POcon543.xml
# POcon549.xml
# POcon591.xml
# POmtg314.xml
# POmtg315.xml
# POmtg316.xml
# POmtg403.xml
# POmtg404.xml
# POmtg439.xml
# POmtg444.xml
# POmtg447.xml
# POmtg539.xml
# POmtg541.xml
# POmtg542.xml
# POmtg546.xml
# POprc465.xml
# POprc522.xml
# POprc557.xml
# POprc558.xml
# POprc559.xml
# POwgd12.xml
# POwgd14.xml
# POwgd243.xml
# POwgd26.xml
# POwgd317.xml
# POwgd325.xml
# POwgd37.xml
# POwgd375.xml
# POwgd378.xml
# POwgd442.xml
# POwgd449.xml
# POwgd510.xml
# POwgd524.xml
# POwsd256.xml
# POwsd257.xml
# POwsd258.xml
# POwsd266.xml
# POwsd372.xml
# POwsd374.xml
# POwsd376.xml
# POwsd379.xml
# PRcon29.xml
# PRcon531.xml
# PRcon534.xml
# PRcon535.xml
# PRcon536.xml
# PRcon550.xml
# PRcon599.xml
# PRint30.xml
# PRint33.xml
# PRint595.xml
# PRint597.xml
# PRint602.xml
# PRint603.xml
# PRpan1.xml
# PRpan13.xml
# PRpan225.xml
# PRpan252.xml
# PRpan294.xml
# PRpan585.xml
# PRqas18.xml
# PRqas19.xml
# PRqas224.xml
# PRqas407.xml
# PRqas409.xml
# PRqas495.xml
# PRwgd537.xml

# %%
pos_tagged['EDcon250.xml']
# Out:
# {('EDcon250_S1', 'EDcon250_u_1'): [('f_prego', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_10'): [('f_passt', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_13'): [('yeah', 'PAfPA'),
#   ('yes', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('big', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_15'): [('big', 'PAfPA'),
#   ('pizza', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('small', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_19'): [('one', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('f_toscana', 'PAfPA'),
#   ('medium', 'PAfPA'),
#   ('okay', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_27'): [('for', 'PAfPA'), ('you', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_29'): [('f_margherita', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_3'): [('f_gemuese', 'PAfPA'),
#   ('f_lasagne', 'PAfPA'),
#   ('f_gerne', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_31'): [('okay', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('thank', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('_3', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_33'): [('f_darf', 'PAfPA'),
#   ('f_ich', 'PAfPA'),
#   ('f_speisekarte', 'PAfPA'),
#   ('f_oder', 'PAfPA'),
#   ('f_brauchen', 'PAfPA'),
#   ('f_sie', 'PAfPA'),
#   ('f_noch', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_35'): [('f_danke', 'PAfPA'),
#   ('f_vielmals', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_5'): [('f_faschierte', 'PAfPA'),
#   ('f_sehr', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_7'): [('f_nur', 'PAfPA'), ('f_gruene', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_8'): [('f_kleinen', 'PAfPA'),
#   ('f_gruenen', 'PAfPA'),
#   ('f_mit', 'PAfPA'),
#   ('f_essig', 'PAfPA'),
#   ('f_und', 'PAfPA'),
#   ('f_oel', 'PAfPA'),
#   ('f_oder', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_842'): [('f_schmeckt', 'PAfPA'),
#   ("f_'s", 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_845'): [('f_danke', 'PAfPA'),
#   ('f_vielmals', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S1', 'EDcon250_u_847'): [('f_dankeschoen', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_101'): [('oh', 'PAfPA'), ('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_114'): [('hm', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_122'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_140'): [('no', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('n-n', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_142'): [('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('came', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('f_bremen', 'PAfPA'),
#   ('now', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('work', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('f_bremen', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_144'): [('so', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('finished', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('s_phd', 'PAfPA'),
#   ('last', 'PAfPA'),
#   ('year', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_146'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('done', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_148'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_151'): [('@@', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_154'): [('so', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('enjoying', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('erasmus', 'PAfPA'),
#   ('year', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_156'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_158'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_160'): [('oh', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('social', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_162'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_164'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_166'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_174'): [('and', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('integrated', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('erasmus', 'PAfPA'),
#   ('student', 'PAfPA'),
#   ('network', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_176'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_178'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('meet', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('other', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_180'): [('okay', 'PAfPA'), ('yeah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_182'): [('are', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('many', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_184'): [('many', 'PAfPA'), ('erasmus', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_186'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_187'): [('wow', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_189'): [('hm', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_2'): [('f_eine', 'PAfPA'),
#   ('f_lasagne', 'PAfPA'),
#   ('f_a', 'PAfPA'),
#   ('f_la', 'PAfPA'),
#   ('f_contessa', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_203'): [('@@', 'PAfPA'), ('@@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_215'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_221'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_255'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_275'): [('mm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_278'): [('mhm', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_285'): [('yeah', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('interesting', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_296'): [('@', 'PAfPA'), ('@@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_301'): [('@@', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_313'): [('yeah', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_315'): [('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('experiencing', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('differences', 'PAfPA'),
#   ('between', 'PAfPA'),
#   ('south', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('north', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('moment', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_319'): [('well', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_320'): [('probably', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('czech', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('slovak', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('i-', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('understand', 'PAfPA'),
#   ('each', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('sometimes', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('phrases', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_324'): [('or', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('words', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_326'): [('pronunciations', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_329'): [('yeah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_336'): [('and', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('bavaria', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('southern', 'PAfPA'),
#   ('part', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('germany', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_tirol', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('f_salzburg', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('language', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('similar', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('culture', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('quite', 'PAfPA'),
#   ('similar', 'PAfPA'),
#   ('actually', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_347'): [('@', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_354'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_360'): [('@@@', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('xxx', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('@@@@', 'PAfPA'),
#   ('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_364'): [('take', 'PAfPA'),
#   ('half', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_376'): [('f_dobre', 'PAfPA'),
#   ('f_dobre', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('anything', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_378'): [('what', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('f_dobre', 'PAfPA'),
#   ('mean', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_380'): [('good', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_382'): [('yeah', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_385'): [('no', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('ahead', 'PAfPA'),
#   ('please', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_387'): [('@@', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_389'): [('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_415'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_419'): [('f_ja', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_421'): [('a', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('smaller', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_423'): [('and', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('still', 'PAfPA'),
#   ('hungry', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('sure', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_426'): [('@@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('@@@@', 'PAfPA'),
#   ('@@@@', 'PAfPA'),
#   ('hh', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_430'): [('yes', 'PAfPA'),
#   ('mhm', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('two', 'PAfPA'),
#   ('friends', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('visiting', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_9', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_433'): [('not', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('mainly', 'PAfPA'),
#   ('once', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('conference', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('once', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('conference', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('daily', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('day', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_435'): [('so', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('much', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('improve', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@@@@@', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('network', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_437'): [('@@@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_439'): [('exactly', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('must', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_45'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_455'): [('and', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('classes', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('a_[firstname1]', 'PAfPA'),
#   ('erm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_457'): [('in', 'PAfPA'),
#   ('english', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('exception', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_460'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_462'): [('uhu', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_464'): [('_0', 'PAfPA'),
#   ('sorry', 'PAfPA'),
#   ('sorry', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_471'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_48'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_480'): [('@', 'PAfPA'), ('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_483'): [('f_hier', 'PAfPA'),
#   ('f_bitte', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_dankeschoen', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_485'): [('f_dankeschoen', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_487'): [('hm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_493'): [('@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_497'): [('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_511'): [('@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_52'): [('hm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_521'): [('mhm', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_525'): [('hm', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_547'): [('and', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('work', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('translator', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_549'): [('headphones', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('but', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_551'): [('like', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('idea', 'PAfPA'),
#   ('behind', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('sit', 'PAfPA'),
#   ('next', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('you', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_553'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_555'): [('he', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_557'): [('oh', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_568'): [('@@', 'PAfPA'),
#   ('@@@@', 'PAfPA'),
#   ('@@@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_578'): [('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('has', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('microphone', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('a', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_580'): [('oh', 'PAfPA'), ('yah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_582'): [('oh', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('erm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_585'): [('mm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_589'): [('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_591'): [('so', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('lecturer', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('hear', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('translator', 'PAfPA'),
#   ('says', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_593'): [('not', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('would', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_595'): [('he', 'PAfPA'),
#   ('probably', 'PAfPA'),
#   ('would', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('understand', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('anyway', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('hear', 'PAfPA'),
#   ('him', 'PAfPA'),
#   ('\n\nlike\n\n', 'PAfPA'),
#   ('\nlike\n', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_598'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_603'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_614'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_616'): [('is', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('yours', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_619'): [('ah', 'PAfPA'), ('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_622'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_623'): [('everybody', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('yawning', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('sleeping', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('_5', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_628'): [('@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_630'): [('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('beginning', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_633'): [('@@', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('yawning', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_654'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('long', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_656'): [('not', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('long', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('istanbul', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_672'): [('@@', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_674'): [('is', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('soccer', 'PAfPA'),
#   ('team', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_676'): [('no', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_679'): [('okay', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_693'): [('is', 'PAfPA'),
#   ('turkey', 'PAfPA'),
#   ('playing', 'PAfPA'),
#   ('turkey', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('playing', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('hm', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_696'): [('they', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('lost', 'PAfPA'),
#   ('against', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('swiss', 'PAfPA'),
#   ('right', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_700'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_741'): [('mhm', 'PAfPA'), ('_4', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_751'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_768'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_797'): [('@@', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_809'): [('you', 'PAfPA'),
#   ('pay', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('state', 'PAfPA'),
#   ('universities', 'PAfPA'),
#   ('also', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_811'): [('you', 'PAfPA'),
#   ('pay', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('state', 'PAfPA'),
#   ('universities', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_813'): [('also', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('hm', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_817'): [('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('all', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_819'): [('xx', 'PAfPA'), ('time', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_821'): [('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('rest', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('time', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('week', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_823'): [('oh', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_825'): [('choose', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_84'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_843'): [('f_ja', 'PAfPA'),
#   ('f_war', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('f_danke', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_864'): [('you', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('money', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('university', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_868'): [('for', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('living', 'PAfPA'),
#   ('ex-', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('living', 'PAfPA'),
#   ('expenses', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_870'): [('yes', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_875'): [('oh', 'PAfPA'), ('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_881'): [('ah', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_899'): [('and', 'PAfPA'),
#   ('each', 'PAfPA'),
#   ('department', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('its', 'PAfPA'),
#   ('own', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_901'): [('tests', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_903'): [('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_909'): [('@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_912'): [('four', 'PAfPA'),
#   ('thousand', 'PAfPA'),
#   ('questions', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_917'): [('@@@@', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_922'): [('ah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_924'): [('hm', 'PAfPA'), ('mhm', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_93'): [('so', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('take', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('courses', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_934'): [('yeah', 'PAfPA'), ('yeah', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_939'): [('yes', 'PAfPA'),
#   ('sorry', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_948'): [('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('way', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('turkey', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_95'): [('okay', 'PAfPA')],
#  ('EDcon250_S2', 'EDcon250_u_951'): [('hm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_103'): [('but', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('course', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('another', 'PAfPA'),
#   ('institution', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('vienna', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_105'): [('on', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('course', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('no', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_107'): [('ah', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('okay', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_109'): [('okay', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_111'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('find', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('amazing', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('watched', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('discussion', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('proficient', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('english', 'PAfPA'),
#   ('everybody', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('we-', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('easily', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('start', 'PAfPA'),
#   ('discussing', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('level', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('amazing', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_115'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('imagine', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_118'): [('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_12'): [('i-', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_120'): [('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('way', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('figure', 'PAfPA'),
#   ('out', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('whether', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('f_der', 'PAfPA'),
#   ('f_die', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('f_das', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_124'): [('yah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_126'): [('uhu', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_128'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('two', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('three', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('three', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_130'): [('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_133'): [('what', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('thing', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('don-', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('ca', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('tell', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('ending', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('word', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('example', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('romance', 'PAfPA'),
#   ('languages', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('often', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('endings', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('words', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('which', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_136'): [('whether', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('f_der', 'PAfPA'),
#   ('f_die', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('f_das', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('difficult', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('assume', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_138'): [('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('glad', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('learn', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_149'): [('she', 'PAfPA'),
#   ('she', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('done', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_152'): [('yeah', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('good', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_168'): [('how', 'PAfPA'),
#   ('long', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('been', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('then', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_170'): [('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('staying', 'PAfPA'),
#   ('until', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('end', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('s-', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_172'): [('aha', 'PAfPA'), ('okay', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_190'): [('and', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('activities', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('organize', 'PAfPA'),
#   ('things', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('could', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_193'): [('yeah', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('difficult', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_195'): [('yeah', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'d", 'PAfPA'),
#   ('need', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('person', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('two', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('others', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('thing', 'PAfPA'),
#   ('_7', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_197'): [('are', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('laughing', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_20'): [('@@', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_200'): [('yeah', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('would', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('understand', 'PAfPA'),
#   ('@@@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_204'): [('i', 'PAfPA'),
#   ('always', 'PAfPA'),
#   ('feel', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('ashamed', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('cross', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('border', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('ca', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('speak', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('ca', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('speak', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('slovak', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('shame', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('takes', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('hour', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_206'): [('or', 'PAfPA'),
#   ('s-', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('even', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('suddenly', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('world', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('hh', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_212'): [('hh', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('make', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('effort', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('learn', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('often', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('speak', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_214'): [('i', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('somehow', 'PAfPA'),
#   ('strange', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('make', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('effort', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('always', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('way', 'PAfPA'),
#   ('working', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('way', 'PAfPA'),
#   ('around', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_217'): [('mutual', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_218'): [('yah', 'PAfPA'),
#   ('bratislava', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('nice', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('takes', 'PAfPA'),
#   ('quarter', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('three', 'PAfPA'),
#   ('quarters', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('hour', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_220'): [('many', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('started', 'PAfPA'),
#   ('flying', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('booking', 'PAfPA'),
#   ('their', 'PAfPA'),
#   ('flights', 'PAfPA'),
#   ('now', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('vienna', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('bratislava', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('hh', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_223'): [('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('cheaper', 'PAfPA'),
#   ('airlines', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('cheaper', 'PAfPA'),
#   ('things', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_226'): [('ah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_227'): [('ah', 'PAfPA'),
#   ('yah', 'PAfPA'),
#   ('true', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_229'): [('exactly', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_23'): [('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_231'): [('true', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_234'): [('f_ja', 'PAfPA'), ('f_bitte', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_236'): [('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_hat', 'PAfPA'),
#   ('f_eh', 'PAfPA'),
#   ('f_sonst', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('nobody', 'PAfPA'),
#   ('else', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_238'): [('ordered', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('salad', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_243'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_245'): [('of', 'PAfPA'), ('course', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_247'): [('yeah', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wonder', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('maybe', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('\n\nthere\n\n', 'PAfPA'),
#   ('\nthere\n', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('\n\nthere\n\n', 'PAfPA'),
#   ('\nthere\n', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ("'d", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('same', 'PAfPA'),
#   ('offers', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_250'): [('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_252'): [('yeah', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('course', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_257'): [('of', 'PAfPA'), ('course', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_259'): [('yeah', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_263'): [('which', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('many', 'PAfPA'),
#   ('euros', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_270'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_282'): [('also', 'PAfPA'),
#   ('the-', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('the-', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('cheap', 'PAfPA'),
#   ('flights', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('rome', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('oh', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_291'): [('oh', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('surely', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_295'): [('yeah', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('huge', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_297'): [('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('huge', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_300'): [('now', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('half', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('half', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('normal', 'PAfPA'),
#   ('one', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_302'): [('ah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_304'): [('so', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('remove', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('microphone', 'PAfPA'),
#   ('afterwards', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_306'): [('@@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_308'): [('@@@', 'PAfPA'), ('_17', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_310'): [('erm', 'PAfPA'),
#   ('ooph', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('difficult', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('germany', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_312'): [('so', 'PAfPA'),
#   ('big', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('ma-', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('dif-', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_314'): [('er', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('customs', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('different', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_317'): [('yeah', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('tell', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_328'): [('dialects', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('many', 'PAfPA'),
#   ('dialects', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('austria', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_330'): [('sometimes', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('hard', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('be', 'PAfPA'),
#   ('understood', 'PAfPA'),
#   ('mutually', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('\n\nyou\n\n', 'PAfPA'),
#   ('\nyou\n', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('\n\nknow\n\n', 'PAfPA'),
#   ('\nknow\n', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_332'): [('if', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('p-', 'PAfPA'),
#   ('person', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('western', 'PAfPA'),
#   ('parts', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('austria', 'PAfPA'),
#   ('speaks', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('eastern', 'PAfPA'),
#   ('parts', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('difficult', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('understand', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_335'): [('erm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_34'): [('f_nein', 'PAfPA'), ('f_danke', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_340'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_342'): [('definitely', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_351'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_kann', 'PAfPA'),
#   ('f_man', 'PAfPA'),
#   ('f_ein', 'PAfPA'),
#   ('f_sackerl', 'PAfPA'),
#   ('f_vielleicht', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_353'): [('f_na', 'PAfPA'),
#   ('f_da', 'PAfPA'),
#   ('f_haben', 'PAfPA'),
#   ('f_wir', 'PAfPA'),
#   ("f_'s", 'PAfPA'),
#   ('f_ich', 'PAfPA'),
#   ('f_hab', 'PAfPA'),
#   ('f_es', 'PAfPA'),
#   ('f_schon', 'PAfPA'),
#   ('f_da', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_darf', 'PAfPA'),
#   ('f_ich', 'PAfPA'),
#   ('f_mir', 'PAfPA'),
#   ('f_das', 'PAfPA'),
#   ('f_schnell', 'PAfPA'),
#   ('f_ausborgen', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_357'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_359'): [('glad', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('lasagne', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_363'): [('we', 'PAfPA'),
#   ('asked', 'PAfPA'),
#   ('them', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_365'): [('yeah', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('asked', 'PAfPA'),
#   ('them', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('put', 'PAfPA'),
#   ('them', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('bags', 'PAfPA'),
#   ('afterwards', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_384'): [('no', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('\n\nplease\n\n', 'PAfPA'),
#   ('\nplease\n', 'PAfPA'),
#   ('please', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_386'): [('ea-', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('sta-', 'PAfPA'),
#   ('start', 'PAfPA'),
#   ('eating', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_390'): [('@@@', 'PAfPA'),
#   ('@@@@@@@', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_393'): [('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_394'): [('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('thin', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('least', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_398'): [('yeah', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('o-', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_4'): [('er', 'PAfPA'),
#   ('f_lasagne', 'PAfPA'),
#   ('f_al', 'PAfPA'),
#   ('f_forno', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_400'): [('@@', 'PAfPA'), ('_9', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_402'): [('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_404'): [('but', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('too', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_406'): [('very', 'PAfPA'), ('thick', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_407'): [('@@@', 'PAfPA'),
#   ('hh', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('will', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('things', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_41'): [('the', 'PAfPA'),
#   ('thing', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('get', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('tired', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('big', 'PAfPA'),
#   ('lunch', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_410'): [('@', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('true', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('american', 'PAfPA'),
#   ('pizzas', 'PAfPA'),
#   ('look', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('huh', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_412'): [('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('extremely', 'PAfPA'),
#   ('quick', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_414'): [('they', 'PAfPA'),
#   ('must', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('big', 'PAfPA'),
#   ('pizza', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('oven', 'PAfPA'),
#   ('also', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_417'): [('f_ich', 'PAfPA'),
#   ('f_muss', 'PAfPA'),
#   ('f_mir', 'PAfPA'),
#   ('f_das', 'PAfPA'),
#   ('f_nochmal', 'PAfPA'),
#   ('f_stehlen', 'PAfPA'),
#   ('f_bitte', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_420'): [('f_der', 'PAfPA'),
#   ('f_schmeckt', 'PAfPA'),
#   ('f_irgendwie', 'PAfPA'),
#   ('f_nach', 'PAfPA'),
#   ('f_nicht', 'PAfPA'),
#   ('f_sehr', 'PAfPA'),
#   ('f_viel', 'PAfPA'),
#   ('_6', 'PAfPA'),
#   ('hi-', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('ok-', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('better', 'PAfPA'),
#   ('off', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('lasagne', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_422'): [('a', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('smaller', 'PAfPA'),
#   ('_3', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_425'): [('we', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('grab', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('couple', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_427'): [('pieces', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_429'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('staying', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('over', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('weekend', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('until', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_43'): [('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('afternoon', 'PAfPA'),
#   ('session', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('thing', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_431'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_432'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('traveling', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('lot', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('job', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_434'): [('yeah', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_436'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_438'): [('and', 'PAfPA'),
#   ('tell', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('necessary', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('somewhere', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_440'): [('hm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_441'): [('and', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('slovakia', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('learn', 'PAfPA'),
#   ('english', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('school', 'PAfPA'),
#   ('already', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_443'): [('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('start', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_445'): [('uhu', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('uhu', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_447'): [('depending', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('focus', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_449'): [('ah', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('uhu', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_451'): [('uhu', 'PAfPA'),
#   ('uhu', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_453'): [('yeah', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_466'): [('f_gesundheit', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_47'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('saw', 'PAfPA'),
#   ('them', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('quite', 'PAfPA'),
#   ('big', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wh-', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('entered', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('quite', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_481'): [('oh', 'PAfPA'), ('no', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_490'): [('the', 'PAfPA'),
#   ('transla-', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('translator', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_50'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('coming', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('session', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('slovakia', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_500'): [('but', 'PAfPA'), ('he', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_502'): [('but', 'PAfPA'), ('he', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_503'): [('but', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('paid', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_507'): [('normally', 'PAfPA'),
#   ('ooph', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_512'): [('@@', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_515'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_519'): [('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('fine', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_522'): [('amazing', 'PAfPA'), ('_3', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_524'): [('mhm', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_531'): [('yah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S3', 'EDcon250_u_54'): [('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('er', 'PAfPA'),
# ...
#   ('is', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('still', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('\n\nbehind\n\n', 'PAfPA'),
#   ('\nbehind\n', 'PAfPA'),
#   ('behind', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_726'): [('where', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_728'): [('yeah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_730'): [('kurdistan', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_732'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_734'): [('no', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_735'): [('who', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('or', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_739'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_742'): [('and', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('happened', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('east', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_744'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('around', 'PAfPA'),
#   ('izmir', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('or', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_746'): [('is', 'PAfPA'),
#   ('some-', 'PAfPA'),
#   ('somewhere', 'PAfPA'),
#   ('izmir', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('west', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_748'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_750'): [('cos', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('remembered', 'PAfPA'),
#   ('another', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('name', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('town', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_756'): [('@@@@', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_759'): [('@@', 'PAfPA'), ('_5', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_762'): [('yeah', 'PAfPA'),
#   ('probably', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('hungry', 'PAfPA'),
#   ('dog', 'PAfPA'),
#   ('waiting', 'PAfPA'),
#   ('somewhere', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('backyard', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_767'): [('xxx', 'PAfPA'),
#   ('x', 'PAfPA'),
#   ('xx', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_772'): [('what', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_774'): [('department', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_776'): [('in', 'PAfPA'),
#   ('fact', 'PAfPA'),
#   ('our', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('based', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('created', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('law', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_778'): [('because', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('department', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('law', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('last', 'PAfPA'),
#   ('year', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('year', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('all', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('law', 'PAfPA'),
#   ('economy', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_781'): [('actually', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('modern', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('new', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_783'): [('two', 'PAfPA'),
#   ('years', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_785'): [('two', 'PAfPA'),
#   ('years', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('already', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('there', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_787'): [('yeah', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_791'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_807'): [('yeah', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_815'): [('but', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('whole', 'PAfPA'),
#   ('day', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('whole', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('whole', 'PAfPA'),
#   ('weekend', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_824'): [('yep', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_839'): [('f_xxxx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xxxx', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xxxx', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_857'): [('mhm', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_858'): [('f_xx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_877'): [('two', 'PAfPA'), ('terms', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_879'): [('on', 'PAfPA'),
#   ('average', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_886'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_889'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_892'): [('cos', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('end', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('high', 'PAfPA'),
#   ('school', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('maturity', 'PAfPA'),
#   ('exam', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('write', 'PAfPA'),
#   ('another', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('sometimes', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('much', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('difficult', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_895'): [('er', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('exactly', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('choose', 'PAfPA'),
#   ('first', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('department', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('xx', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_897'): [('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('you', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_898'): [('yeah', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('requirements', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('example', 'PAfPA'),
#   ('our', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_900'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_902'): [('yeah', 'PAfPA'), ('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_904'): [('er', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('example', 'PAfPA'),
#   ('our', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('write', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('intelligence', 'PAfPA'),
#   ('test', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('something', 'PAfPA'),
#   ('similar', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('were', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('intelligence', 'PAfPA'),
#   ('tasks', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('logic', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('something', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('but', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_906'): [('yeah', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('exactly', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('physics', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_908'): [('and', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('s-', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('second', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('thing', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('wrote', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('english', 'PAfPA'),
#   ('exam', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('example', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_910'): [('er', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('another', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('law', 'PAfPA'),
#   ('school', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('bratislava', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('slovakia', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('were', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('requirements', 'PAfPA'),
#   ('history', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('lot', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('history', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('four', 'PAfPA'),
#   ('thousand', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('questions', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('history', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('master', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('the', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_913'): [('four', 'PAfPA'), ('thousand', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_915'): [('yeah', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_919'): [('looks', 'PAfPA'),
#   ('looks', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('this', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_921'): [('and', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('four', 'PAfPA'),
#   ('thousand', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_925'): [('and', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('has', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('best', 'PAfPA'),
#   ('name', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('or', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_928'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_929'): [('now', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('deciding', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('which', 'PAfPA'),
#   ('school', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('g-', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('enough', 'PAfPA'),
#   ('information', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_931'): [('everybody', 'PAfPA'),
#   ('thought', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('a_[name1]', 'PAfPA'),
#   ('university', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('oh', 'PAfPA'),
#   ('a_[name1]', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_935'): [('yeah', 'PAfPA'), ('so', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_940'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_942'): [('precisely', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_944'): [('yeah', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_946'): [('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_949'): [('erm', 'PAfPA')],
#  ('EDcon250_S6', 'EDcon250_u_952'): [('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('kind', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('exam', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('high', 'PAfPA'),
#   ('school', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_233'): [('f_salat', 'PAfPA'),
#   ('f_essig', 'PAfPA'),
#   ('f_oel', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_235'): [('f_bitte', 'PAfPA'),
#   ('f_schoen', 'PAfPA'),
#   ('f_mahlzeit', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_341'): [('so', 'PAfPA'), ('f_toscana', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_345'): [('f_margherita', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_349'): [('f_proscuitto', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_352'): [('f_ja', 'PAfPA'),
#   ('f_haben', 'PAfPA'),
#   ('f_wir', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_482'): [('f_la', 'PAfPA'),
#   ('f_contessa', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_484'): [('f_bitte', 'PAfPA'),
#   ('f_schoen', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_aufpassen', 'PAfPA'),
#   ('f_teller', 'PAfPA'),
#   ('f_ist', 'PAfPA'),
#   ('f_sehr', 'PAfPA'),
#   ('f_heiss', 'PAfPA'),
#   ('f_mahlzeit', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_753'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('finish', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_755'): [('yah', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_757'): [('@@', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_849'): [('finished', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_850'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('finished', 'PAfPA')],
#  ('EDcon250_S7', 'EDcon250_u_852'): [('yah', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_199'): [('@@', 'PAfPA'), ('@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_22'): [('@@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_288'): [('@@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_305'): [('@@@@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_370'): [('@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_424'): [('@@@', 'PAfPA'), ('@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_575'): [('@@@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_601'): [('@@@@@', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_666'): [('@@@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_677'): [('@@', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_721'): [('@@', 'PAfPA')],
#  ('EDcon250_SS', 'EDcon250_u_764'): [('@@@', 'PAfPA'), ('@@@@', 'PAfPA')],
#  ('EDcon250_SX-2', 'EDcon250_u_132'): [('hm', 'PAfPA')],
#  ('EDcon250_SX-2', 'EDcon250_u_475'): [('mm', 'PAfPA')],
#  ('EDcon250_SX-3', 'EDcon250_u_36'): [('no', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon250_SX-3', 'EDcon250_u_517'): [('@', 'PAfPA')],
#  ('EDcon250_SX-3', 'EDcon250_u_698'): [('@@@', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon250_SX-3', 'EDcon250_u_716'): [('mhm', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon250_SX-4', 'EDcon250_u_715'): [('where', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('already', 'PAfPA'),
#   ('issued', 'PAfPA'),
#   ('something', 'PAfPA')],
#  ('EDcon250_SX-4', 'EDcon250_u_717'): [('because', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('football', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('football', 'PAfPA'),
#   ('players', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('now', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('look', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('history', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('our', 'PAfPA'),
#   ('football', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('france', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_SX-6', 'EDcon250_u_17'): [('medium', 'PAfPA')],
#  ('EDcon250_SX-6', 'EDcon250_u_854'): [('yeah', 'PAfPA')],
#  ('EDcon250_SX-f', 'EDcon250_u_374'): [('f_xx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xxx', 'PAfPA'),
#   ('f_xxx', 'PAfPA')],
#  ('EDcon250_SX-f', 'EDcon250_u_617'): [('no', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('n-n', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon250_SX-f', 'EDcon250_u_618'): [('f_nein', 'PAfPA'),
#   ('f_das', 'PAfPA'),
#   ('f_ist', 'PAfPA'),
#   ('f_meins', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_SX-f', 'EDcon250_u_650'): [('two', 'PAfPA'),
#   ('hours', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon250_SX-f', 'EDcon250_u_652'): [('oh', 'PAfPA')]}

# %%
pos_tagged.keys()
# Out:
# dict_keys(['EDcon250.xml', 'EDcon4.xml', 'EDcon496.xml', 'EDcon521.xml', 'EDint328.xml', 'EDint330.xml', 'EDint331.xml', 'EDint604.xml', 'EDint605.xml', 'EDsed251.xml', 'EDsed301.xml', 'EDsed31.xml', 'EDsed362.xml', 'EDsed363.xml', 'EDsed364.xml', 'EDsve421.xml', 'EDsve422.xml', 'EDsve423.xml', 'EDsve451.xml', 'EDsve452.xml', 'EDwgd241.xml', 'EDwgd305.xml', 'EDwgd497.xml', 'EDwgd5.xml', 'EDwgd6.xml', 'EDwsd15.xml', 'EDwsd242.xml', 'EDwsd302.xml', 'EDwsd303.xml', 'EDwsd304.xml', 'EDwsd306.xml', 'EDwsd464.xml', 'EDwsd499.xml', 'EDwsd590.xml', 'EDwsd9.xml', 'LEcon227.xml', 'LEcon228.xml', 'LEcon229.xml', 'LEcon329.xml', 'LEcon351.xml', 'LEcon352.xml', 'LEcon353.xml', 'LEcon405.xml', 'LEcon417.xml', 'LEcon418.xml', 'LEcon420.xml', 'LEcon545.xml', 'LEcon547.xml', 'LEcon548.xml', 'LEcon560.xml', 'LEcon562.xml', 'LEcon565.xml', 'LEcon566.xml', 'LEcon573.xml', 'LEcon575.xml', 'LEcon8.xml', 'LEint551.xml', 'LEint552.xml', 'LEint553.xml', 'LEint554.xml', 'LEint555.xml', 'PBcon594.xml', 'PBmtg269.xml', 'PBmtg27.xml', 'PBmtg280.xml', 'PBmtg3.xml', 'PBmtg300.xml', 'PBmtg414.xml', 'PBmtg462.xml', 'PBmtg463.xml', 'PBpan10.xml', 'PBpan25.xml', 'PBpan28.xml', 'PBpan581.xml', 'PBqas410.xml', 'PBqas411.xml', 'PBqas412.xml', 'PBqas523.xml', 'PBsve426.xml', 'PBsve430.xml', 'PBsve434.xml', 'PBsve435.xml', 'PBsve436.xml', 'PBsve437.xml', 'POcon543.xml', 'POcon549.xml', 'POcon591.xml', 'POmtg314.xml', 'POmtg315.xml', 'POmtg316.xml', 'POmtg403.xml', 'POmtg404.xml', 'POmtg439.xml', 'POmtg444.xml', 'POmtg447.xml', 'POmtg539.xml', 'POmtg541.xml', 'POmtg542.xml', 'POmtg546.xml', 'POprc465.xml', 'POprc522.xml', 'POprc557.xml', 'POprc558.xml', 'POprc559.xml', 'POwgd12.xml', 'POwgd14.xml', 'POwgd243.xml', 'POwgd26.xml', 'POwgd317.xml', 'POwgd325.xml', 'POwgd37.xml', 'POwgd375.xml', 'POwgd378.xml', 'POwgd442.xml', 'POwgd449.xml', 'POwgd510.xml', 'POwgd524.xml', 'POwsd256.xml', 'POwsd257.xml', 'POwsd258.xml', 'POwsd266.xml', 'POwsd372.xml', 'POwsd374.xml', 'POwsd376.xml', 'POwsd379.xml', 'PRcon29.xml', 'PRcon531.xml', 'PRcon534.xml', 'PRcon535.xml', 'PRcon536.xml', 'PRcon550.xml', 'PRcon599.xml', 'PRint30.xml', 'PRint33.xml', 'PRint595.xml', 'PRint597.xml', 'PRint602.xml', 'PRint603.xml', 'PRpan1.xml', 'PRpan13.xml', 'PRpan225.xml', 'PRpan252.xml', 'PRpan294.xml', 'PRpan585.xml', 'PRqas18.xml', 'PRqas19.xml', 'PRqas224.xml', 'PRqas407.xml', 'PRqas409.xml', 'PRqas495.xml', 'PRwgd537.xml'])

# %%
pos_tagged['EDcon4.xml']
# Out:
# {('EDcon4_S1', 'EDcon4_u_1'): [('running', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_2'): [('with', 'PAfPA'), ('whom', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_3'): [('a_[firstname1]', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('belgium', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_4'): [('okay', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_5'): [('and', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S3', 'EDcon4_u_6'): [('oh', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('sorry', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_7'): [('and', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('problem', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('she', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('running', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_8'): [('@@', 'PAfPA'), ('@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_9'): [('the', 'PAfPA'),
#   ('whole', 'PAfPA'),
#   ('city', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_10'): [('@@', 'PAfPA'), ('@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_11'): [('i', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('be', 'PAfPA'),
#   ('back', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('saw', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('were', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('smart', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('find', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('answer', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('went', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('tourist', 'PAfPA'),
#   ('office', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('asked', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('answers', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_12'): [('okay', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_13'): [('and', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('gave', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_14'): [('ah', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('complete', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('erm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_15'): [('mhm', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_16'): [('okay', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_17'): [('how', 'PAfPA'),
#   ('tall', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('tower', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_18'): [('the', 'PAfPA'),
#   ('tower', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_19'): [('yeah', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('church', 'PAfPA'),
#   ('tower', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('old', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('guy', 'PAfPA'),
#   ('who', 'PAfPA'),
#   ('died', 'PAfPA'),
#   ('here', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('founder', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('city', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_20'): [('was', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('his', 'PAfPA'),
#   ('name', 'PAfPA'),
#   ('a_[lastname2]', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_21'): [('no', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_22'): [('mister', 'PAfPA'),
#   ('a_[lastname2]', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_23'): [('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('skipped', 'PAfPA'),
#   ('few', 'PAfPA'),
#   ('questions', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('participate', 'PAfPA'),
#   ('actively', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_24'): [('okay', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('a_[firstname3]', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('upset', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('a_[firstname3]', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_25'): [('about', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_26'): [('he', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('upset', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_27'): [('about', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_28'): [('that', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('participate', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_29'): [('well', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('went', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('physically', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_30'): [('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_31'): [('only', 'PAfPA'),
#   ('physically', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_32'): [('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_33'): [('not', 'PAfPA'),
#   ('mentally', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_34'): [('@', 'PAfPA'), ('@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_35'): [('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('trying', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('walk', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_36'): [('er', 'PAfPA'), ('challenging', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_37'): [('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_38'): [('@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_39'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('am', 'PAfPA'),
#   ('mentally', 'PAfPA'),
#   ('challenged', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_40'): [('okay', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_41'): [('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('sad', 'PAfPA'),
#   ('true', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('sad', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('true', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_42'): [('mhm', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('life', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('life', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('anything', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('soap', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('me', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('class', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('thinking', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('stress', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_43'): [('@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_44'): [('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('smell', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_45'): [('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_46'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_47'): [('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('once', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('liked', 'PAfPA'),
#   ('milk', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('honey', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_48'): [('no', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_49'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('lavender', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_50'): [('yeah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_51'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('x', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('xx', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_52'): [('mhm', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('\n\nlike\n\n', 'PAfPA'),
#   ('\nlike\n', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('xxxx', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_53'): [('i', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('milk', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('honey', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('\n\nalmond\n\n', 'PAfPA'),
#   ('\nalmond\n', 'PAfPA'),
#   ('almond', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_54'): [('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('sweet', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_55'): [('but', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('still', 'PAfPA'),
#   ('smells', 'PAfPA'),
#   ('nice', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_56'): [('yeah', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_3', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_57'): [('say', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('_7', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('happened', 'PAfPA'),
#   ('yesterday', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_58'): [('yesterday', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_59'): [('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('four', 'PAfPA'),
#   ('glasses', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('wine', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_60'): [('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('martini', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('raki', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('two', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_61'): [('f_rakia', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_62'): [('raki', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_63'): [('jesus', 'PAfPA'), ('no', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_64'): [('some', 'PAfPA'),
#   ('glasses', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('wine', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_65'): [('it', 'PAfPA'), ('is', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_66'): [('and', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('beer', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('\n\npretty\n\n', 'PAfPA'),
#   ('\npretty\n', 'PAfPA'),
#   ('pretty', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_67'): [('no', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('wasted', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_68'): [('beer', 'PAfPA'),
#   ('y-', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('why', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('dancing', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_69'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_70'): [('anything', 'PAfPA'),
#   ('\n\nlike\n\n', 'PAfPA'),
#   ('\nlike\n', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_71'): [('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('water', 'PAfPA'),
#   ('before', 'PAfPA'),
#   ('going', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('bed', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_72'): [('xx', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_73'): [('i', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_74'): [('me', 'PAfPA'),
#   ('neither', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('never', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('water', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('drinking', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_75'): [('i', 'PAfPA'),
#   ('always', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('water', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('remember', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('able', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('stand', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_76'): [('xxxx', 'PAfPA'),
#   ('f_seuf', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_77'): [('yeah', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_78'): [('okay', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_79'): [('or', 'PAfPA'),
#   ('f_senf', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_80'): [('hh', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_81'): [('okay', 'PAfPA'),
#   ('check', 'PAfPA'),
#   ('both', 'PAfPA'),
#   ('words', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_82'): [('f_reself', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_self', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_83'): [('f_senf', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_84'): [('s_seleve', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_85'): [('f_senf', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_86'): [('yeah', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('s_n', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_87'): [('s_csenf', 'PAfPA'), ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_88'): [('f_senf', 'PAfPA'), ('okay', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_89'): [('f_senf', 'PAfPA'),
#   ('_3', 'PAfPA'),
#   ('mhm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('f_senf', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_90'): [('and', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('started', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('showing', 'PAfPA'),
#   ('up', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_ketchup', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_senf', 'PAfPA'),
#   ('f_ketchup', 'PAfPA'),
#   ('f_senf', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_91'): [('good', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_92'): [('and', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('kept', 'PAfPA'),
#   ('telling', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('five', 'PAfPA'),
#   ('minutes', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('said', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('i', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_93'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('\n\nlike\n\n', 'PAfPA'),
#   ('\nlike\n', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('tape', 'PAfPA'),
#   ('recorder', 'PAfPA'),
#   ('broken', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_94'): [('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('yesterday', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('actually', 'PAfPA'),
#   ('told', 'PAfPA'),
#   ('him', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('ca', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('f_gott', 'PAfPA'),
#   ('f_strafe', 'PAfPA'),
#   ('f_oesterreich', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('started', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_95'): [('hello', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_96'): [('hello', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_97'): [('hello', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_98'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('arrived', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_99'): [('no', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('make', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('chick', 'PAfPA'),
#   ('break', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_SX-2', 'EDcon4_u_100'): [('sh', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_101'): [('@@@', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_102'): [('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('leave', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_103'): [('a', 'PAfPA'),
#   ('chick', 'PAfPA'),
#   ('f_fick', 'PAfPA'),
#   ('f_fick', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_104'): [('chick', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('loudly', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_4', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('will', 'PAfPA'),
#   ('never', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('alcohol', 'PAfPA'),
#   ('never', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('life', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_105'): [('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('raki', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_106'): [('oh', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('recorded', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_107'): [('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('who', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_108'): [('okay', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('f_rakia', 'PAfPA'),
#   ('right', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_109'): [('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('give', 'PAfPA'),
#   ('names', 'PAfPA'),
#   ('\n\nthat\n\n', 'PAfPA'),
#   ('\nthat\n', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_110'): [('@@@', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('raki', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_111'): [('okay', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_112'): [('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('raki', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('country', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_113'): [('did', 'PAfPA'), ('you', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_114'): [('so', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('yours', 'PAfPA'),
#   ('right', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_115'): [('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('turkish', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_116'): [('ah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('see', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_117'): [('somebody', 'PAfPA'),
#   ('else', 'PAfPA'),
#   ("'s", 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_118'): [('ah', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_119'): [('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('f_rakia', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('once', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('never', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('make', 'PAfPA'),
#   ('mistake', 'PAfPA'),
#   ('pf', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_120'): [('is', 'PAfPA'), ('this', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_121'): [('no', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('like', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_122'): [('half', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('bottle', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('same', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_123'): [('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('raki', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_124'): [('no', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('london', 'PAfPA'),
#   ('last', 'PAfPA'),
#   ('year', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('stuff', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_125'): [('but', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('yesterday', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('turk', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('lot', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('much', 'PAfPA'),
#   ('less', 'PAfPA'),
#   ('than', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('others', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('macedonia', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('again', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_126'): [('@@', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S5', 'EDcon4_u_127'): [('oops', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon4_SS', 'EDcon4_u_128'): [('@@@', 'PAfPA')],
#  ('EDcon4_S5', 'EDcon4_u_129'): [('f_tschuldigung', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_130'): [('@@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_131'): [('with', 'PAfPA'),
#   ('dinner', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('made', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('plums', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_132'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('one', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_133'): [('sweeter', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_134'): [('plums', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('grapes', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_135'): [('sweeter', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_136'): [('yeah', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_137'): [('yes', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_138'): [('a_[S3]', 'PAfPA'),
#   ('sweeter', 'PAfPA'),
#   ('no', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_139'): [('yeah', 'PAfPA'),
#   ('yes', 'PAfPA'),
#   ('yes', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_140'): [('but', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('guy', 'PAfPA'),
#   ('told', 'PAfPA'),
#   ('me', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('f_rakia', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('crying', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('said', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('way', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_141'): [('what', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S5', 'EDcon4_u_142'): [('yeah', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_143'): [('cry', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_144'): [('yeah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_145'): [('why', 'PAfPA'), ('cry', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_146'): [('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('drank', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('glass', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('shot', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('f_rakia', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('started', 'PAfPA'),
#   ('crying', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_147'): [('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('yesterday', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('er', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_148'): [('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('try', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('thanks', 'PAfPA'),
#   ('god', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('try', 'PAfPA'),
#   ('it', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_149'): [('no', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('put', 'PAfPA')],
#  ('EDcon4_S3', 'EDcon4_u_150'): [('no', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('y-', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('smell', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('notice', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('difference', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('other', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('smell', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_151'): [('mhm', 'PAfPA'), ('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_152'): [('hm', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('remember', 'PAfPA'),
#   ('actually', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('smell', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_153'): [('no', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('mean', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_154'): [('it', 'PAfPA'), ('started', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_155'): [('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('having', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('sme-', 'PAfPA'),
#   ('specific', 'PAfPA'),
#   ('smell', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('herbs', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('regular', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('plums', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_156'): [('f_xx', 'PAfPA'),
#   ('f_x', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_xx', 'PAfPA'),
#   ('f_x', 'PAfPA'),
#   ('f_xx', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_157'): [('but', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('may', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('been', 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('strong', 'PAfPA'),
#   ('because', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_158'): [('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('eighty', 'PAfPA'),
#   ('per', 'PAfPA'),
#   ('cent', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_159'): [('yeah', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('much', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_160'): [('f_diesen', 'PAfPA'),
#   ('f_leberknoedel', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_161'): [('my', 'PAfPA'),
#   ('father', 'PAfPA'),
#   ('usually', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('maybe', 'PAfPA'),
#   ('fifty', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('sixty', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_162'): [('f_das', 'PAfPA'),
#   ('f_broetchen', 'PAfPA'),
#   ('f_gulasch', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_163'): [('but', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('doing', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('by', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('guy', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('albania', 'PAfPA'),
#   ('just', 'PAfPA'),
#   ('brought', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('stuff', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('england', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('hh', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('having', 'PAfPA'),
#   ('his', 'PAfPA'),
#   ('birthday', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('h-', 'PAfPA'),
#   ('home-made', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_164'): [('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_165'): [('so', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('knew', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('eighty', 'PAfPA'),
#   ('per', 'PAfPA'),
#   ('cent', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_166'): [('yeah', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('our', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('usually', 'PAfPA'),
#   ('home-made', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('lots', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('prepare', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('home', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_167'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('prohibited', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('poland', 'PAfPA'),
#   ('actually', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_168'): [('er', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('think', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('which', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('manufactured', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_169'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_170'): [('is', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('strong', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_171'): [('mhm', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('forty', 'PAfPA'),
#   ('\n\nper\n\n', 'PAfPA'),
#   ('\nper\n', 'PAfPA'),
#   ('per', 'PAfPA'),
#   ('\n\ncent\n\n', 'PAfPA'),
#   ('\ncent\n', 'PAfPA'),
#   ('cent', 'PAfPA'),
#   ('limit', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('spirit', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_172'): [('yes', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_173'): [('maximum', 'PAfPA'),
#   ('forty', 'PAfPA'),
#   ('per', 'PAfPA'),
#   ('cent', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('at', 'PAfPA'),
#   ('home', 'PAfPA'),
#   ('usually', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('fifteen', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('sixteen', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_174'): [('mhm', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_175'): [('it', 'PAfPA'),
#   ('depends', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_176'): [('mhm', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_177'): [('but', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('strong', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('hm', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_178'): [('f_die', 'PAfPA'),
#   ('f_bevoelkerungsdichte', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_179'): [('i', 'PAfPA'),
#   ('am', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('going', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('life', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('more', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_180'): [('why', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_181'): [('yes', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('problem', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('f_rakia', 'PAfPA'),
#   ('as', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('usually', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('eat', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_182'): [('i', 'PAfPA'),
#   ('thought', 'PAfPA'),
#   ('xx', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_183'): [('yeah', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_184'): [('when', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('drink', 'PAfPA'),
#   ('it', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_185'): [('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_186'): [('we', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('make', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('special', 'PAfPA'),
#   ('salad', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('which', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('called', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_shopska', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_187'): [('out', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('what', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_188'): [('f_shopska', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_189'): [('yes', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_190'): [('all', 'PAfPA'), ('right', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_191'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('made', 'PAfPA'),
#   ('out', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('tomatoes', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('cucumbers', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_192'): [('mhm', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_193'): [('erm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('onion', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('cheese', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_194'): [('aha', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_195'): [('no', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('must', 'PAfPA'),
#   ('be', 'PAfPA'),
#   ('good', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_196'): [('yes', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('very', 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('eat', 'PAfPA'),
#   ('salad', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('f_com', 'PAfPA'),
#   ('f_commo', 'PAfPA'),
#   ('f_se', 'PAfPA'),
#   ('f_pronunce', 'PAfPA'),
#   ('f_accetato', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_197'): [('f_com', 'PAfPA'),
#   ('f_affectato', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_198'): [('f_a-', 'PAfPA'),
#   ('f_af-', 'PAfPA'),
#   ('f_affetato', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_199'): [('f_affetata', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_200'): [('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('italian', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('matter', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_201'): [('no', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_202'): [('ah', 'PAfPA'),
#   ('feta', 'PAfPA'),
#   ('f_xxx', 'PAfPA'),
#   ('feta', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_203'): [('n-n', 'PAfPA'), ('no', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_204'): [('feta', 'PAfPA'),
#   ('cheese', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('mean', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_205'): [('no', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('salamis', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('types', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('salamis', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_206'): [('oh', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_207'): [('okay', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_208'): [('er', 'PAfPA'),
#   ('yellow', 'PAfPA'),
#   ('cheese', 'PAfPA'),
#   ('er', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_209'): [('mhm', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('hard', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_210'): [('yeah', 'PAfPA'), ('f_kashkaval', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_211'): [('f_kashkawa', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_212'): [('mhm', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_213'): [('yeah', 'PAfPA'),
#   ('f_kashkawa', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_kashkawa', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_214'): [('no', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_215'): [('no', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_216'): [('they', 'PAfPA'),
#   ("'ll", 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_217'): [('we', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('normal', 'PAfPA'),
#   ('cheese', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_218'): [('you', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('call', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('thing', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_219'): [('\n\nlike\n\n', 'PAfPA'),
#   ('\nlike\n', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('sort', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('mozzarella', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_220'): [('yes', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_221'): [('mhm', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_222'): [('something', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('mozzarella', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('which', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('much', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('consistent', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_223'): [('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_224'): [('mhm', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_225'): [('yeah', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('fat', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_226'): [('is', 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('feta', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_227'): [('yeah', 'PAfPA'),
#   ('mozzarella', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('mozzarella', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_228'): [('f_kashkaval', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('fat', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_229'): [('f_kashkaval', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('fat', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_230'): [('yes', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('fat', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('feta', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_231'): [('okay', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_232'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('totally', 'PAfPA'),
#   ('different', 'PAfPA'),
#   ('thing', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_233'): [('okay', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_234'): [('and', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('how', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('does', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('take', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('quickly', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_235'): [('yeah', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('ate', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('last', 'PAfPA'),
#   ('year', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('and', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_236'): [('because', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('you', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_237'): [('if', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('eat', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_238'): [('hh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('head', 'PAfPA'),
#   ('hurts', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_239'): [('here', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_240'): [('my', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('nose', 'PAfPA'),
#   ('hurts', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('why', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_241'): [('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('why', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wan-', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wanted', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('shower', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('bar', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('soap', 'PAfPA'),
#   ('dropped', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_242'): [('@@@', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_243'): [('@@@', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_244'): [('tube', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('up', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('up', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('hit', 'PAfPA'),
#   ('myself', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA')],
#  ('EDcon4_SX-1', 'EDcon4_u_245'): [('@@@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_246'): [('erm', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('o_bvuff', 'PAfPA')],
#  ('EDcon4_SX-4', 'EDcon4_u_247'): [('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_248'): [('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_249'): [('being', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('poland', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('prison', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('when', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_250'): [('@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_251'): [('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('in', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_252'): [('@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_253'): [('what', 'PAfPA'),
#   ('when', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('prison', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('poland', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_254'): [('@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_255'): [('what', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('ah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('talking', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('doing', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('legal', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('legal', 'PAfPA'),
#   ('clinic', 'PAfPA'),
#   ('course', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('advising', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('poor', 'PAfPA'),
#   ('people', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_256'): [('mhm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_257'): [('some', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('them', 'PAfPA'),
#   ('were', 'PAfPA'),
#   ('criminals', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('could', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('afford', 'PAfPA'),
#   ('their', 'PAfPA'),
#   ('lawyer', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_258'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_259'): [('so', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('were', 'PAfPA'),
#   ('talking', 'PAfPA'),
#   ('really', 'PAfPA'),
#   ('weird', 'PAfPA'),
#   ('stories', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('said', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('standing', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('shower', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('freshman', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('prison', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_260'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('gosh', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_261'): [('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('taking', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('soap', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('putting', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('floor', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_262'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_263'): [('and', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('soap', 'PAfPA'),
#   ('yes', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_264'): [('deliberately', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_265'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_266'): [('ah', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('yes', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_267'): [('@@@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_268'): [('well', 'PAfPA'), ('@@', 'PAfPA')],
#  ('EDcon4_SX-f', 'EDcon4_u_269'): [('ah', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_270'): [('f_nicht', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_271'): [('f_nicht', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_272'): [('yeah', 'PAfPA'),
#   ('f_nicht', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_273'): [('bad', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_274'): [('yeah', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('tell', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('story', 'PAfPA'),
#   ('erm', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_275'): [('f_xxxxxx', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_276'): [('okay', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('going', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('read', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('probably', 'PAfPA'),
#   ('@@', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_277'): [('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('staying', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('lunch', 'PAfPA'),
#   ('or', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_278'): [('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('presentation', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('presentation', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_279'): [('okay', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_280'): [('oh', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_281'): [('yeah', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_282'): [('i', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('already', 'PAfPA'),
#   ('done', 'PAfPA'),
#   ('that', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_283'): [('good', 'PAfPA'),
#   ('luck', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('tomorrow', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_284'): [('i', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('pictures', 'PAfPA'),
#   ('from', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('internet', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_285'): [('oh', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('nice', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_286'): [('yeah', 'PAfPA'),
#   ('them', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('pictures', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_287'): [('i', 'PAfPA'),
#   ("'m", 'PAfPA'),
#   ('doing', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_288'): [('what', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('doing', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_289'): [('haeh', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_290'): [('what', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('doing', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('presentation', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_291'): [('my', 'PAfPA'),
#   ('hometown', 'PAfPA'),
#   ('@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_292'): [('ok-', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('am', 'PAfPA'),
#   ('doing', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('festival', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('f_sighisora', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S4', 'EDcon4_u_293'): [('oh', 'PAfPA'),
# ...
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_907'): [('my', 'PAfPA'),
#   ('essay', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('spanish', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_908'): [('so', 'PAfPA'), ('_3', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_909'): [('@@@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_910'): [('@', 'PAfPA'),
#   ('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_3', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('ca', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('read', 'PAfPA'),
#   ('him', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('this', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('_4', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_911'): [('ag-', 'PAfPA'),
#   ('a-', 'PAfPA'),
#   ('argued', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_912'): [('oh', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('would', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('see', 'PAfPA'),
#   ('xxx', 'PAfPA'),
#   ('argument', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('however', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_913'): [('yeah', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('had', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('something', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('praise', 'PAfPA'),
#   ('me', 'PAfPA'),
#   ('too', 'PAfPA'),
#   ('much', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_914'): [('yeah', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('sure', 'PAfPA'),
#   ('\n\nsure\n\n', 'PAfPA'),
#   ('\nsure\n', 'PAfPA'),
#   ('sure', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('erm', 'PAfPA'),
#   ('flattery', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('be', 'PAfPA'),
#   ('xxx', 'PAfPA'),
#   ('\n\nwear\n\n', 'PAfPA'),
#   ('\nwear\n', 'PAfPA'),
#   ('wear', 'PAfPA'),
#   ('_16', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_915'): [('but', 'PAfPA'),
#   ('then', 'PAfPA'),
#   ('he', 'PAfPA'),
#   ('gave', 'PAfPA'),
#   ('me', 'PAfPA'),
#   ('an', 'PAfPA'),
#   ('s_a', 'PAfPA'),
#   ('so', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('_5', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_916'): [('yes', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('approval', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('happy', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_917'): [('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('it', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_918'): [('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('read', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_919'): [('no', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('situation', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_920'): [('i', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('care', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('compete', 'PAfPA'),
#   ('any', 'PAfPA'),
#   ('more', 'PAfPA'),
#   ('anyway', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_921'): [('we', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('compete', 'PAfPA'),
#   ('anyway', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('whatever', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_922'): [('no', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('am', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('lawyer', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_923'): [('ooph', 'PAfPA'),
#   ('hhh', 'PAfPA'),
#   ('_14', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_924'): [('so', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('most', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('v-', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('verbs', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('german', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('need', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_akkusativ', 'PAfPA'),
#   ('right', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_925'): [('yeah', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_926'): [('right', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_927'): [('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('some', 'PAfPA'),
#   ('stupid', 'PAfPA'),
#   ('verbs', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('f_akkusativ', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('da-', 'PAfPA'),
#   ('or', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('f_dativ', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_928'): [('yeah', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_929'): [('aha', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_930'): [('depends', 'PAfPA'),
#   ('on', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('situation', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_931'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('f_wo', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('f_wohin', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('we', 'PAfPA'),
#   ("'ve", 'PAfPA'),
#   ('got', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('exceptions', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('verbs', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('f_dativ', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('only', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_932'): [('i', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ("'re", 'PAfPA'),
#   ('exceptions', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('there', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('verbs', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('f_akkusativ', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('also', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('words', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('f_dativ', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_933'): [('okay', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_934'): [('which', 'PAfPA'),
#   ('are', 'PAfPA'),
#   ('\n\nless\n\n', 'PAfPA'),
#   ('\nless\n', 'PAfPA'),
#   ('less', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_935'): [('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('_41', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_936'): [('@@@', 'PAfPA'),
#   ('silly', 'PAfPA'),
#   ('people', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_937'): [('@@', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_938'): [('@@', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_939'): [('okay', 'PAfPA'),
#   ('_28', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('know', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('expression', 'PAfPA'),
#   ('off', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('record', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_940'): [('off', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('record', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_941'): [('@@@', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_942'): [('@', 'PAfPA'), ('_4', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_943'): [('f_glauben', 'PAfPA'),
#   ('f_gehoeren', 'PAfPA'),
#   ('_23', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('pretty', 'PAfPA'),
#   ('vain', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('read', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('mass', 'PAfPA'),
#   ('of', 'PAfPA'),
#   ('these', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_944'): [('haeh', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_945'): [('like', 'PAfPA'),
#   ('all', 'PAfPA'),
#   ('over', 'PAfPA'),
#   ('again', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_946'): [('no', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('am', 'PAfPA'),
#   ('looking', 'PAfPA'),
#   ('for', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('xxxx', 'PAfPA'),
#   ('_16', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_947'): [('f_befehlen', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('command', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('command', 'PAfPA'),
#   ('right', 'PAfPA'),
#   ('f_befehlen', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_948'): [('to', 'PAfPA'), ('command', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_949'): [('to', 'PAfPA'),
#   ('order', 'PAfPA'),
#   ('yeah', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_950'): [('f_befehlen', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('order', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_951'): [('f_der', 'PAfPA'),
#   ('f_zoellner', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_befehlt', 'PAfPA'),
#   ('_37', 'PAfPA'),
#   ('f_befehl', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_952'): [('@@', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('_38', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_953'): [('what', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('f_erwidern', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_954'): [('what', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_955'): [('f_erwidern', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('f_erwidern', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_956'): [('to', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('reply', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('rep-', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_957'): [('oh', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('same', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_958'): [('but', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('reply', 'PAfPA'),
#   ('someone', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('reply', 'PAfPA'),
#   ('erm', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_959'): [('to', 'PAfPA'), ('some-', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_960'): [('sentence', 'PAfPA'),
#   ('yeah', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('someone', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_961'): [('okay', 'PAfPA'), ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_962'): [('but', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('want', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('ask', 'PAfPA'),
#   ('him', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('found', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('like', 'PAfPA'),
#   ('if', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('use', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('f_auf', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_963'): [('mhm', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_964'): [('it', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('f_akkusativ', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_965'): [('yeah', 'PAfPA'),
#   ('f_auf', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('accusative', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_966'): [('so', 'PAfPA'),
#   ('why', 'PAfPA'),
#   ('did', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('because', 'PAfPA'),
#   ('they', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('both', 'PAfPA'),
#   ('both', 'PAfPA'),
#   ('_30', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_967'): [('f_danke', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_968'): [('f_danke', 'PAfPA'),
#   ('er', 'PAfPA'),
#   ('okay', 'PAfPA')],
#  ('EDcon4_SX-f', 'EDcon4_u_969'): [('yeah', 'PAfPA'), ('yeah', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_970'): [('thanks', 'PAfPA'), ('_3', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_971'): [('f_fehlen', 'PAfPA'), ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_972'): [('f_fehlen', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('miss', 'PAfPA'),
#   ('_3', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('f_vermissen', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_973'): [('haeh', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_974'): [('sa-', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('say', 'PAfPA'),
#   ('f_vermissen', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_975'): [('okay', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('okay', 'PAfPA'),
#   ('yes', 'PAfPA'),
#   ('_7', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_976'): [('my', 'PAfPA'),
#   ('head', 'PAfPA'),
#   ('hurts', 'PAfPA'),
#   ('_3', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wan', 'PAfPA'),
#   ('na', 'PAfPA'),
#   ('puke', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_977'): [('@', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_978'): [('yeah', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('wan', 'PAfPA'),
#   ('na', 'PAfPA'),
#   ('puke', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('little', 'PAfPA'),
#   ('bit', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_979'): [('@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_980'): [('@', 'PAfPA'),
#   ('what', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_981'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_982'): [('what', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_983'): [('this', 'PAfPA'),
#   ('conversation', 'PAfPA'),
#   ('@@@', 'PAfPA'),
#   ('_8', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_984'): [('that', 'PAfPA'),
#   ('pill', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('good', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_985'): [('@@@@', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_986'): [('was', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('a', 'PAfPA'),
#   ('vomiting', 'PAfPA'),
#   ('pill', 'PAfPA'),
#   ('or', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_987'): [('no', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('caffeine', 'PAfPA'),
#   ('and', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('xxx', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('makes', 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('blood', 'PAfPA'),
#   ('pressure', 'PAfPA'),
#   ('higher', 'PAfPA'),
#   ('_1', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_988'): [('not', 'PAfPA'),
#   ('good', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('f_nicht', 'PAfPA'),
#   ('f_gut', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('but', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_989'): [('but', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('xxx', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('well', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('do', 'PAfPA'),
#   ("n't", 'PAfPA'),
#   ('xx', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ("'s", 'PAfPA'),
#   ('your', 'PAfPA'),
#   ('change', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_990'): [('@', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('why', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_991'): [('cos', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('gave', 'PAfPA'),
#   ('me', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('ninety', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_992'): [('hh', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_993'): [('and', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('was', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('seventy', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_994'): [('okay', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('one', 'PAfPA'),
#   ('@', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('euro', 'PAfPA'),
#   ('cent', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('come', 'PAfPA'),
#   ('on', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_995'): [('no', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_996'): [('oh', 'PAfPA'),
#   ('my', 'PAfPA'),
#   ('god', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_997'): [('@@', 'PAfPA'),
#   ('no', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('you', 'PAfPA'),
#   ('started', 'PAfPA'),
#   ('that', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_998'): [('f_gut', 'PAfPA'),
#   ('_4', 'PAfPA'),
#   ('@', 'PAfPA')],
#  ('EDcon4_S1', 'EDcon4_u_999'): [('f_gefallen', 'PAfPA'),
#   ('_1', 'PAfPA'),
#   ('f_gefallen', 'PAfPA'),
#   ('f_gehoeren', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('f_gehorchen', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('obey', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('f_gehorchen', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('obey', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('time', 'PAfPA'),
#   ('_0', 'PAfPA')],
#  ('EDcon4_S2', 'EDcon4_u_1000'): [('yeah', 'PAfPA'),
#   ('it', 'PAfPA'),
#   ('is', 'PAfPA'),
#   ('_0', 'PAfPA'),
#   ('twenty', 'PAfPA'),
#   ('past', 'PAfPA'),
#   ('_2', 'PAfPA'),
#   ('but', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('have', 'PAfPA'),
#   ('to', 'PAfPA'),
#   ('i', 'PAfPA'),
#   ('can', 'PAfPA'),
#   ('not', 'PAfPA'),
#   ('go', 'PAfPA'),
#   ('with', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('bag', 'PAfPA'),
#   ('in', 'PAfPA'),
#   ('the', 'PAfPA'),
#   ('soap', 'PAfPA'),
#   ('_2', 'PAfPA')],
#  ...}

# %%
for l in pos_tagged['EDcon4.xml']:
    print(pos_tagged['EDcon4.xml'][l])
# Out:
# [('running', 'PAfPA'), ('we', 'PAfPA'), ('got', 'PAfPA'), ('_0', 'PAfPA')]
# [('with', 'PAfPA'), ('whom', 'PAfPA')]
# [('a_[firstname1]', 'PAfPA'), ('_0', 'PAfPA'), ('the', 'PAfPA'), ('belgium', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('and', 'PAfPA'), ('@@', 'PAfPA'), ('and', 'PAfPA'), ('er', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('_0', 'PAfPA'), ('sorry', 'PAfPA'), ('_1', 'PAfPA')]
# [('and', 'PAfPA'), ('the', 'PAfPA'), ('problem', 'PAfPA'), ('was', 'PAfPA'), ('that', 'PAfPA'), ('she', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('running', 'PAfPA')]
# [('@@', 'PAfPA'), ('@', 'PAfPA')]
# [('the', 'PAfPA'), ('whole', 'PAfPA'), ('city', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@', 'PAfPA'), ('@', 'PAfPA')]
# [('i', 'PAfPA'), ("'ll", 'PAfPA'), ('be', 'PAfPA'), ('back', 'PAfPA'), ('and', 'PAfPA'), ('we', 'PAfPA'), ('saw', 'PAfPA'), ('the', 'PAfPA'), ('people', 'PAfPA'), ('because', 'PAfPA'), ('the', 'PAfPA'), ('people', 'PAfPA'), ('were', 'PAfPA'), ('so', 'PAfPA'), ('smart', 'PAfPA'), ('that', 'PAfPA'), ('_0', 'PAfPA'), ('they', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('find', 'PAfPA'), ('the', 'PAfPA'), ('answer', 'PAfPA'), ('_0', 'PAfPA'), ('but', 'PAfPA'), ('they', 'PAfPA'), ('went', 'PAfPA'), ('to', 'PAfPA'), ('the', 'PAfPA'), ('tourist', 'PAfPA'), ('office', 'PAfPA'), ('and', 'PAfPA'), ('they', 'PAfPA'), ('asked', 'PAfPA'), ('for', 'PAfPA'), ('answers', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA')]
# [('and', 'PAfPA'), ('they', 'PAfPA'), ('gave', 'PAfPA')]
# [('ah', 'PAfPA'), ('because', 'PAfPA'), ('they', 'PAfPA'), ('had', 'PAfPA'), ('to', 'PAfPA'), ('complete', 'PAfPA'), ('some', 'PAfPA'), ('erm', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('okay', 'PAfPA')]
# [('how', 'PAfPA'), ('tall', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('tower', 'PAfPA'), ('or', 'PAfPA'), ('_0', 'PAfPA')]
# [('the', 'PAfPA'), ('tower', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('church', 'PAfPA'), ('tower', 'PAfPA'), ('_1', 'PAfPA'), ('and', 'PAfPA'), ('er', 'PAfPA'), ('how', 'PAfPA'), ('old', 'PAfPA'), ('was', 'PAfPA'), ('the', 'PAfPA'), ('guy', 'PAfPA'), ('who', 'PAfPA'), ('died', 'PAfPA'), ('here', 'PAfPA'), ('and', 'PAfPA'), ('he', 'PAfPA'), ('was', 'PAfPA'), ('the', 'PAfPA'), ('founder', 'PAfPA'), ('of', 'PAfPA'), ('the', 'PAfPA'), ('city', 'PAfPA'), ('_0', 'PAfPA')]
# [('was', 'PAfPA'), ('he', 'PAfPA'), ('was', 'PAfPA'), ('his', 'PAfPA'), ('name', 'PAfPA'), ('a_[lastname2]', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA')]
# [('mister', 'PAfPA'), ('a_[lastname2]', 'PAfPA')]
# [('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA'), ('because', 'PAfPA'), ('i', 'PAfPA'), ('skipped', 'PAfPA'), ('few', 'PAfPA'), ('questions', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('participate', 'PAfPA'), ('actively', 'PAfPA'), ('@', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('_2', 'PAfPA'), ('so', 'PAfPA'), ('erm', 'PAfPA'), ('a_[firstname3]', 'PAfPA'), ('was', 'PAfPA'), ('not', 'PAfPA'), ('upset', 'PAfPA'), ('_0', 'PAfPA'), ('a_[firstname3]', 'PAfPA'), ('_0', 'PAfPA')]
# [('about', 'PAfPA'), ('what', 'PAfPA'), ('_0', 'PAfPA')]
# [('he', 'PAfPA'), ('was', 'PAfPA'), ('not', 'PAfPA'), ('upset', 'PAfPA'), ('_1', 'PAfPA')]
# [('about', 'PAfPA'), ('_0', 'PAfPA')]
# [('that', 'PAfPA'), ('_0', 'PAfPA'), ('you', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('participate', 'PAfPA'), ('_0', 'PAfPA')]
# [('well', 'PAfPA'), ('i', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('went', 'PAfPA'), ('there', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('physically', 'PAfPA'), ('there', 'PAfPA'), ('@@', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('only', 'PAfPA'), ('physically', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('not', 'PAfPA'), ('mentally', 'PAfPA'), ('_1', 'PAfPA')]
# [('@', 'PAfPA'), ('@', 'PAfPA')]
# [('i', 'PAfPA'), ('was', 'PAfPA'), ('trying', 'PAfPA'), ('to', 'PAfPA'), ('walk', 'PAfPA')]
# [('er', 'PAfPA'), ('challenging', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('yeah', 'PAfPA'), ('i', 'PAfPA'), ('am', 'PAfPA'), ('mentally', 'PAfPA'), ('challenged', 'PAfPA'), ('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('_0', 'PAfPA')]
# [('that', 'PAfPA'), ("'s", 'PAfPA'), ('sad', 'PAfPA'), ('true', 'PAfPA'), ('_0', 'PAfPA'), ('sad', 'PAfPA'), ('but', 'PAfPA'), ('true', 'PAfPA'), ('_1', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_1', 'PAfPA'), ('so', 'PAfPA'), ('is', 'PAfPA'), ('life', 'PAfPA'), ('_0', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('life', 'PAfPA'), ('_1', 'PAfPA'), ('we', 'PAfPA'), ('xx', 'PAfPA'), ('anything', 'PAfPA'), ('with', 'PAfPA'), ('soap', 'PAfPA'), ('with', 'PAfPA'), ('me', 'PAfPA'), ('in', 'PAfPA'), ('class', 'PAfPA'), ('and', 'PAfPA'), ('they', 'PAfPA'), ('are', 'PAfPA'), ('thinking', 'PAfPA'), ('like', 'PAfPA'), ('this', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('stress', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('but', 'PAfPA'), ('i', 'PAfPA'), ('like', 'PAfPA'), ('the', 'PAfPA'), ('smell', 'PAfPA'), ('of', 'PAfPA'), ('it', 'PAfPA'), ('_1', 'PAfPA')]
# [('i', 'PAfPA'), ('know', 'PAfPA'), ('_1', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('had', 'PAfPA'), ('it', 'PAfPA'), ('once', 'PAfPA'), ('i', 'PAfPA'), ('liked', 'PAfPA'), ('milk', 'PAfPA'), ('and', 'PAfPA'), ('honey', 'PAfPA'), ('_2', 'PAfPA')]
# [('no', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('lavender', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('x', 'PAfPA'), ('like', 'PAfPA'), ('the', 'PAfPA'), ('xx', 'PAfPA'), ('xx', 'PAfPA')]
# [('mhm', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('\n\nlike\n\n', 'PAfPA'), ('\nlike\n', 'PAfPA'), ('like', 'PAfPA'), ('xxxx', 'PAfPA'), ('you', 'PAfPA'), ('know', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('like', 'PAfPA'), ('er', 'PAfPA'), ('milk', 'PAfPA'), ('and', 'PAfPA'), ('honey', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('like', 'PAfPA'), ('\n\nalmond\n\n', 'PAfPA'), ('\nalmond\n', 'PAfPA'), ('almond', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ('is', 'PAfPA'), ('_0', 'PAfPA'), ('too', 'PAfPA'), ('sweet', 'PAfPA'), ('_2', 'PAfPA')]
# [('but', 'PAfPA'), ('it', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ('still', 'PAfPA'), ('smells', 'PAfPA'), ('nice', 'PAfPA'), ('_1', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_1', 'PAfPA'), ('@', 'PAfPA'), ('_0', 'PAfPA'), ('@@', 'PAfPA'), ('_3', 'PAfPA')]
# [('say', 'PAfPA'), ('no', 'PAfPA'), ('more', 'PAfPA'), ('say', 'PAfPA'), ('no', 'PAfPA'), ('more', 'PAfPA'), ('_7', 'PAfPA'), ('well', 'PAfPA'), ('i', 'PAfPA'), ('got', 'PAfPA'), ('other', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA'), ('what', 'PAfPA'), ('happened', 'PAfPA'), ('yesterday', 'PAfPA'), ('it', 'PAfPA'), ('just', 'PAfPA'), ('_1', 'PAfPA')]
# [('yesterday', 'PAfPA')]
# [('i', 'PAfPA'), ('had', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('four', 'PAfPA'), ('glasses', 'PAfPA'), ('of', 'PAfPA'), ('wine', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('had', 'PAfPA'), ('martini', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('er', 'PAfPA'), ('raki', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('two', 'PAfPA')]
# [('f_rakia', 'PAfPA')]
# [('raki', 'PAfPA'), ('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('jesus', 'PAfPA'), ('no', 'PAfPA')]
# [('some', 'PAfPA'), ('glasses', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('wine', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ('is', 'PAfPA')]
# [('and', 'PAfPA'), ('_0', 'PAfPA'), ('beer', 'PAfPA'), ('_0', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('\n\npretty\n\n', 'PAfPA'), ('\npretty\n', 'PAfPA'), ('pretty', 'PAfPA')]
# [('no', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('so', 'PAfPA'), ('wasted', 'PAfPA')]
# [('beer', 'PAfPA'), ('y-', 'PAfPA'), ('you', 'PAfPA'), ('know', 'PAfPA'), ('why', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('dancing', 'PAfPA'), ('so', 'PAfPA'), ('i', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('anything', 'PAfPA'), ('\n\nlike\n\n', 'PAfPA'), ('\nlike\n', 'PAfPA'), ('like', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('drink', 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('drink', 'PAfPA'), ('water', 'PAfPA'), ('before', 'PAfPA'), ('going', 'PAfPA'), ('to', 'PAfPA'), ('bed', 'PAfPA'), ('_0', 'PAfPA')]
# [('xx', 'PAfPA')]
# [('i', 'PAfPA'), ('think', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA')]
# [('me', 'PAfPA'), ('neither', 'PAfPA'), ('i', 'PAfPA'), ('never', 'PAfPA'), ('drink', 'PAfPA'), ('water', 'PAfPA'), ('when', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('drinking', 'PAfPA')]
# [('i', 'PAfPA'), ('always', 'PAfPA'), ('drink', 'PAfPA'), ('water', 'PAfPA'), ('_1', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('remember', 'PAfPA'), ('that', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ("n't", 'PAfPA'), ('able', 'PAfPA'), ('to', 'PAfPA'), ('stand', 'PAfPA'), ('_2', 'PAfPA')]
# [('xxxx', 'PAfPA'), ('f_seuf', 'PAfPA'), ('_1', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_2', 'PAfPA')]
# [('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('or', 'PAfPA'), ('f_senf', 'PAfPA'), ('_0', 'PAfPA')]
# [('hh', 'PAfPA'), ('@@', 'PAfPA')]
# [('okay', 'PAfPA'), ('check', 'PAfPA'), ('both', 'PAfPA'), ('words', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_reself', 'PAfPA'), ('_0', 'PAfPA'), ('f_self', 'PAfPA')]
# [('f_senf', 'PAfPA')]
# [('s_seleve', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_senf', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('with', 'PAfPA'), ('an', 'PAfPA'), ('s_n', 'PAfPA'), ('_0', 'PAfPA')]
# [('s_csenf', 'PAfPA'), ('_2', 'PAfPA')]
# [('f_senf', 'PAfPA'), ('okay', 'PAfPA')]
# [('f_senf', 'PAfPA'), ('_3', 'PAfPA'), ('mhm', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('f_senf', 'PAfPA'), ('yeah', 'PAfPA'), ('_2', 'PAfPA')]
# [('and', 'PAfPA'), ('he', 'PAfPA'), ('started', 'PAfPA'), ('er', 'PAfPA'), ('like', 'PAfPA'), ('showing', 'PAfPA'), ('up', 'PAfPA'), ('_1', 'PAfPA'), ('f_ketchup', 'PAfPA'), ('_0', 'PAfPA'), ('f_senf', 'PAfPA'), ('f_ketchup', 'PAfPA'), ('f_senf', 'PAfPA'), ('_0', 'PAfPA')]
# [('good', 'PAfPA'), ('_0', 'PAfPA')]
# [('and', 'PAfPA'), ('he', 'PAfPA'), ('kept', 'PAfPA'), ('telling', 'PAfPA'), ('like', 'PAfPA'), ('_0', 'PAfPA'), ('five', 'PAfPA'), ('minutes', 'PAfPA'), ('_0', 'PAfPA'), ('he', 'PAfPA'), ('said', 'PAfPA'), ('that', 'PAfPA'), ('i', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('\n\nlike\n\n', 'PAfPA'), ('\nlike\n', 'PAfPA'), ('like', 'PAfPA'), ('did', 'PAfPA'), ('he', 'PAfPA'), ('_0', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA'), ('tape', 'PAfPA'), ('recorder', 'PAfPA'), ('broken', 'PAfPA'), ('_0', 'PAfPA')]
# [('erm', 'PAfPA'), ('_0', 'PAfPA'), ('yesterday', 'PAfPA'), ('i', 'PAfPA'), ('actually', 'PAfPA'), ('told', 'PAfPA'), ('him', 'PAfPA'), ('that', 'PAfPA'), ('erm', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('ca', 'PAfPA'), ("n't", 'PAfPA'), ('say', 'PAfPA'), ('f_gott', 'PAfPA'), ('f_strafe', 'PAfPA'), ('f_oesterreich', 'PAfPA'), ('no', 'PAfPA'), ('more', 'PAfPA'), ('because', 'PAfPA'), ('i', 'PAfPA'), ('started', 'PAfPA'), ('_0', 'PAfPA')]
# [('hello', 'PAfPA'), ('_0', 'PAfPA')]
# [('hello', 'PAfPA'), ('_0', 'PAfPA')]
# [('hello', 'PAfPA')]
# [('do', 'PAfPA'), ('you', 'PAfPA'), ('arrived', 'PAfPA'), ('there', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('can', 'PAfPA'), ('make', 'PAfPA'), ('a', 'PAfPA'), ('chick', 'PAfPA'), ('break', 'PAfPA'), ('for', 'PAfPA'), ('you', 'PAfPA'), ('_0', 'PAfPA')]
# [('sh', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('you', 'PAfPA'), ('can', 'PAfPA'), ('leave', 'PAfPA'), ('what', 'PAfPA'), ('_0', 'PAfPA')]
# [('a', 'PAfPA'), ('chick', 'PAfPA'), ('f_fick', 'PAfPA'), ('f_fick', 'PAfPA')]
# [('chick', 'PAfPA'), ('_1', 'PAfPA'), ('but', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('say', 'PAfPA'), ('it', 'PAfPA'), ('loudly', 'PAfPA'), ('@@', 'PAfPA'), ('_4', 'PAfPA'), ('i', 'PAfPA'), ('will', 'PAfPA'), ('never', 'PAfPA'), ('drink', 'PAfPA'), ('your', 'PAfPA'), ('alcohol', 'PAfPA'), ('never', 'PAfPA'), ('in', 'PAfPA'), ('my', 'PAfPA'), ('life', 'PAfPA')]
# [('but', 'PAfPA'), ('i', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('in', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA'), ('do', 'PAfPA'), ('you', 'PAfPA'), ('have', 'PAfPA'), ('more', 'PAfPA'), ('erm', 'PAfPA'), ('_0', 'PAfPA'), ('er', 'PAfPA'), ('raki', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('we', 'PAfPA'), ('are', 'PAfPA'), ('recorded', 'PAfPA'), ('so', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('but', 'PAfPA'), ('they', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA'), ('who', 'PAfPA'), ('we', 'PAfPA'), ('are', 'PAfPA'), ('so', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA'), ('but', 'PAfPA'), ('you', 'PAfPA'), ('have', 'PAfPA'), ('a', 'PAfPA'), ('f_rakia', 'PAfPA'), ('right', 'PAfPA')]
# [('do', 'PAfPA'), ("n't", 'PAfPA'), ('give', 'PAfPA'), ('names', 'PAfPA'), ('\n\nthat\n\n', 'PAfPA'), ('\nthat\n', 'PAfPA'), ('that', 'PAfPA')]
# [('@@@', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA'), ('er', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('have', 'PAfPA'), ('raki', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('_0', 'PAfPA')]
# [('but', 'PAfPA'), ('you', 'PAfPA'), ('you', 'PAfPA'), ('do', 'PAfPA'), ('have', 'PAfPA'), ('raki', 'PAfPA'), ('in', 'PAfPA'), ('your', 'PAfPA'), ('country', 'PAfPA'), ('_0', 'PAfPA')]
# [('did', 'PAfPA'), ('you', 'PAfPA')]
# [('so', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('yours', 'PAfPA'), ('right', 'PAfPA')]
# [('it', 'PAfPA'), ('was', 'PAfPA'), ('turkish', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA')]
# [('ah', 'PAfPA'), ('i', 'PAfPA'), ('see', 'PAfPA')]
# [('somebody', 'PAfPA'), ('else', 'PAfPA'), ("'s", 'PAfPA')]
# [('ah', 'PAfPA'), ('okay', 'PAfPA'), ('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('i', 'PAfPA'), ('had', 'PAfPA'), ('f_rakia', 'PAfPA'), ('only', 'PAfPA'), ('once', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('never', 'PAfPA'), ('had', 'PAfPA'), ('to', 'PAfPA'), ('make', 'PAfPA'), ('mistake', 'PAfPA'), ('pf', 'PAfPA')]
# [('is', 'PAfPA'), ('this', 'PAfPA')]
# [('no', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('like', 'PAfPA')]
# [('half', 'PAfPA'), ('of', 'PAfPA'), ('the', 'PAfPA'), ('bottle', 'PAfPA'), ('but', 'PAfPA'), ('the', 'PAfPA'), ('same', 'PAfPA')]
# [('but', 'PAfPA'), ('you', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('drink', 'PAfPA'), ('raki', 'PAfPA')]
# [('no', 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('because', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('it', 'PAfPA'), ('like', 'PAfPA'), ('_0', 'PAfPA'), ('in', 'PAfPA'), ('london', 'PAfPA'), ('last', 'PAfPA'), ('year', 'PAfPA'), ('_0', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('that', 'PAfPA'), ('stuff', 'PAfPA'), ('_0', 'PAfPA')]
# [('but', 'PAfPA'), ('this', 'PAfPA'), ('is', 'PAfPA'), ('from', 'PAfPA'), ('er', 'PAfPA'), ('that', 'PAfPA'), ('one', 'PAfPA'), ('yesterday', 'PAfPA'), ('is', 'PAfPA'), ('from', 'PAfPA'), ('turk', 'PAfPA'), ('_1', 'PAfPA'), ('and', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('erm', 'PAfPA'), ('_0', 'PAfPA'), ('a', 'PAfPA'), ('lot', 'PAfPA'), ('more', 'PAfPA'), ('er', 'PAfPA'), ('much', 'PAfPA'), ('less', 'PAfPA'), ('than', 'PAfPA'), ('_1', 'PAfPA'), ('others', 'PAfPA'), ('you', 'PAfPA'), ('can', 'PAfPA'), ('in', 'PAfPA'), ('macedonia', 'PAfPA'), ('is', 'PAfPA'), ('from', 'PAfPA'), ('_0', 'PAfPA'), ('again', 'PAfPA')]
# [('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('oops', 'PAfPA'), ('@@', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('f_tschuldigung', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@', 'PAfPA'), ('_0', 'PAfPA'), ('@', 'PAfPA')]
# [('with', 'PAfPA'), ('dinner', 'PAfPA'), ('we', 'PAfPA'), ('have', 'PAfPA'), ('er', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('have', 'PAfPA'), ('this', 'PAfPA'), ('one', 'PAfPA'), ('as', 'PAfPA'), ('well', 'PAfPA'), ('but', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('also', 'PAfPA'), ('have', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('one', 'PAfPA'), ('we', 'PAfPA'), ('drink', 'PAfPA'), ('more', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('one', 'PAfPA'), ('made', 'PAfPA'), ('of', 'PAfPA'), ('plums', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('i', 'PAfPA'), ('had', 'PAfPA'), ('that', 'PAfPA'), ('one', 'PAfPA')]
# [('sweeter', 'PAfPA')]
# [('plums', 'PAfPA'), ('or', 'PAfPA'), ('grapes', 'PAfPA')]
# [('sweeter', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('yes', 'PAfPA')]
# [('a_[S3]', 'PAfPA'), ('sweeter', 'PAfPA'), ('no', 'PAfPA')]
# [('yeah', 'PAfPA'), ('yes', 'PAfPA'), ('yes', 'PAfPA')]
# [('but', 'PAfPA'), ('the', 'PAfPA'), ('guy', 'PAfPA'), ('told', 'PAfPA'), ('me', 'PAfPA'), ('that', 'PAfPA'), ('okay', 'PAfPA'), ('you', 'PAfPA'), ("'ll", 'PAfPA'), ('have', 'PAfPA'), ('f_rakia', 'PAfPA'), ('and', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('crying', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('said', 'PAfPA'), ('no', 'PAfPA'), ('way', 'PAfPA'), ('_0', 'PAfPA')]
# [('what', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('cry', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('why', 'PAfPA'), ('cry', 'PAfPA')]
# [('and', 'PAfPA'), ('i', 'PAfPA'), ('drank', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('glass', 'PAfPA'), ('of', 'PAfPA'), ('like', 'PAfPA'), ('the', 'PAfPA'), ('shot', 'PAfPA'), ('of', 'PAfPA'), ('f_rakia', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('started', 'PAfPA'), ('crying', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('that', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA')]
# [('it', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('that', 'PAfPA'), ('one', 'PAfPA'), ('yesterday', 'PAfPA'), ('or', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('er', 'PAfPA')]
# [('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('try', 'PAfPA'), ('the', 'PAfPA'), ('er', 'PAfPA'), ('thanks', 'PAfPA'), ('god', 'PAfPA'), ('as', 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('try', 'PAfPA'), ('it', 'PAfPA')]
# [('no', 'PAfPA'), ('but', 'PAfPA'), ('if', 'PAfPA'), ('you', 'PAfPA'), ('put', 'PAfPA')]
# [('no', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('_0', 'PAfPA'), ('y-', 'PAfPA'), ('you', 'PAfPA'), ('can', 'PAfPA'), ('just', 'PAfPA'), ('smell', 'PAfPA'), ('it', 'PAfPA'), ('and', 'PAfPA'), ('you', 'PAfPA'), ("'ll", 'PAfPA'), ('you', 'PAfPA'), ("'ll", 'PAfPA'), ('notice', 'PAfPA'), ('the', 'PAfPA'), ('difference', 'PAfPA'), ('because', 'PAfPA'), ('the', 'PAfPA'), ('other', 'PAfPA'), ('one', 'PAfPA'), ('does', 'PAfPA'), ("n't", 'PAfPA'), ('smell', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('mhm', 'PAfPA')]
# [('hm', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('remember', 'PAfPA'), ('actually', 'PAfPA'), ('the', 'PAfPA'), ('smell', 'PAfPA'), ('but', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('mean', 'PAfPA')]
# [('it', 'PAfPA'), ('started', 'PAfPA')]
# [('it', 'PAfPA'), ('was', 'PAfPA'), ('not', 'PAfPA'), ('having', 'PAfPA'), ('any', 'PAfPA'), ('sme-', 'PAfPA'), ('specific', 'PAfPA'), ('smell', 'PAfPA'), ('like', 'PAfPA'), ('herbs', 'PAfPA'), ('then', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('er', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('regular', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('plums', 'PAfPA')]
# [('f_xx', 'PAfPA'), ('f_x', 'PAfPA'), ('f_xx', 'PAfPA'), ('f_xx', 'PAfPA'), ('f_xx', 'PAfPA'), ('f_x', 'PAfPA'), ('f_xx', 'PAfPA')]
# [('but', 'PAfPA'), ('it', 'PAfPA'), ('it', 'PAfPA'), ('may', 'PAfPA'), ('have', 'PAfPA'), ('been', 'PAfPA'), ('very', 'PAfPA'), ('strong', 'PAfPA'), ('because', 'PAfPA')]
# [('it', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('eighty', 'PAfPA'), ('per', 'PAfPA'), ('cent', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('too', 'PAfPA'), ('much', 'PAfPA')]
# [('f_diesen', 'PAfPA'), ('f_leberknoedel', 'PAfPA')]
# [('my', 'PAfPA'), ('father', 'PAfPA'), ('usually', 'PAfPA'), ('does', 'PAfPA'), ('it', 'PAfPA'), ('maybe', 'PAfPA'), ('fifty', 'PAfPA'), ('or', 'PAfPA'), ('sixty', 'PAfPA')]
# [('f_das', 'PAfPA'), ('f_broetchen', 'PAfPA'), ('f_gulasch', 'PAfPA')]
# [('but', 'PAfPA'), ('they', 'PAfPA'), ('they', 'PAfPA'), ('are', 'PAfPA'), ('doing', 'PAfPA'), ('it', 'PAfPA'), ('by', 'PAfPA'), ('_0', 'PAfPA'), ('because', 'PAfPA'), ('erm', 'PAfPA'), ('the', 'PAfPA'), ('guy', 'PAfPA'), ('from', 'PAfPA'), ('albania', 'PAfPA'), ('just', 'PAfPA'), ('brought', 'PAfPA'), ('the', 'PAfPA'), ('stuff', 'PAfPA'), ('to', 'PAfPA'), ('england', 'PAfPA'), ('_0', 'PAfPA'), ('hh', 'PAfPA'), ('and', 'PAfPA'), ('he', 'PAfPA'), ('was', 'PAfPA'), ('having', 'PAfPA'), ('his', 'PAfPA'), ('birthday', 'PAfPA'), ('_0', 'PAfPA'), ('and', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('_1', 'PAfPA'), ('h-', 'PAfPA'), ('home-made', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('so', 'PAfPA'), ('he', 'PAfPA'), ('knew', 'PAfPA'), ('that', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('eighty', 'PAfPA'), ('per', 'PAfPA'), ('cent', 'PAfPA')]
# [('yeah', 'PAfPA'), ('it', 'PAfPA'), ('it', 'PAfPA'), ('our', 'PAfPA'), ('it', 'PAfPA'), ('is', 'PAfPA'), ('usually', 'PAfPA'), ('home-made', 'PAfPA'), ('because', 'PAfPA'), ('lots', 'PAfPA'), ('of', 'PAfPA'), ('people', 'PAfPA'), ('do', 'PAfPA'), ('it', 'PAfPA'), ('er', 'PAfPA'), ('prepare', 'PAfPA'), ('it', 'PAfPA'), ('at', 'PAfPA'), ('home', 'PAfPA'), ('_2', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('erm', 'PAfPA'), ('prohibited', 'PAfPA'), ('in', 'PAfPA'), ('poland', 'PAfPA'), ('actually', 'PAfPA'), ('_0', 'PAfPA')]
# [('er', 'PAfPA'), ('i', 'PAfPA'), ('think', 'PAfPA'), ('that', 'PAfPA'), ('the', 'PAfPA'), ('one', 'PAfPA'), ('which', 'PAfPA'), ('is', 'PAfPA'), ('er', 'PAfPA'), ('er', 'PAfPA'), ('manufactured', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('is', 'PAfPA'), ('not', 'PAfPA'), ('so', 'PAfPA'), ('strong', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('forty', 'PAfPA'), ('\n\nper\n\n', 'PAfPA'), ('\nper\n', 'PAfPA'), ('per', 'PAfPA'), ('\n\ncent\n\n', 'PAfPA'), ('\ncent\n', 'PAfPA'), ('cent', 'PAfPA'), ('limit', 'PAfPA'), ('on', 'PAfPA'), ('spirit', 'PAfPA')]
# [('yes', 'PAfPA')]
# [('maximum', 'PAfPA'), ('forty', 'PAfPA'), ('per', 'PAfPA'), ('cent', 'PAfPA'), ('but', 'PAfPA'), ('people', 'PAfPA'), ('at', 'PAfPA'), ('home', 'PAfPA'), ('usually', 'PAfPA'), ('do', 'PAfPA'), ('it', 'PAfPA'), ('like', 'PAfPA'), ('er', 'PAfPA'), ('fifteen', 'PAfPA'), ('or', 'PAfPA'), ('sixteen', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('it', 'PAfPA'), ('depends', 'PAfPA'), ('how', 'PAfPA'), ('they', 'PAfPA'), ('like', 'PAfPA'), ('it', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('but', 'PAfPA'), ('really', 'PAfPA'), ('strong', 'PAfPA'), ('_1', 'PAfPA'), ('hm', 'PAfPA')]
# [('f_die', 'PAfPA'), ('f_bevoelkerungsdichte', 'PAfPA')]
# [('i', 'PAfPA'), ('am', 'PAfPA'), ('not', 'PAfPA'), ('going', 'PAfPA'), ('to', 'PAfPA'), ('have', 'PAfPA'), ('it', 'PAfPA'), ('in', 'PAfPA'), ('my', 'PAfPA'), ('life', 'PAfPA'), ('any', 'PAfPA'), ('more', 'PAfPA')]
# [('why', 'PAfPA'), ('i', 'PAfPA'), ('like', 'PAfPA'), ('it', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('but', 'PAfPA'), ('the', 'PAfPA'), ('problem', 'PAfPA'), ('is', 'PAfPA'), ('that', 'PAfPA'), ('you', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('drink', 'PAfPA'), ('er', 'PAfPA'), ('f_rakia', 'PAfPA'), ('as', 'PAfPA'), ('er', 'PAfPA'), ('like', 'PAfPA'), ('that', 'PAfPA'), ('_1', 'PAfPA'), ('we', 'PAfPA'), ('usually', 'PAfPA'), ('drink', 'PAfPA'), ('it', 'PAfPA'), ('you', 'PAfPA'), ('you', 'PAfPA'), ('have', 'PAfPA'), ('to', 'PAfPA'), ('eat', 'PAfPA')]
# [('i', 'PAfPA'), ('thought', 'PAfPA'), ('xx', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('when', 'PAfPA'), ('you', 'PAfPA'), ('drink', 'PAfPA'), ('it', 'PAfPA')]
# [('i', 'PAfPA'), ('know', 'PAfPA'), ('_0', 'PAfPA')]
# [('we', 'PAfPA'), ('we', 'PAfPA'), ('make', 'PAfPA'), ('one', 'PAfPA'), ('special', 'PAfPA'), ('salad', 'PAfPA'), ('_0', 'PAfPA'), ('which', 'PAfPA'), ('is', 'PAfPA'), ('called', 'PAfPA'), ('er', 'PAfPA'), ('_0', 'PAfPA'), ('f_shopska', 'PAfPA'), ('_0', 'PAfPA')]
# [('out', 'PAfPA'), ('of', 'PAfPA'), ('what', 'PAfPA')]
# [('f_shopska', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('_0', 'PAfPA')]
# [('all', 'PAfPA'), ('right', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('er', 'PAfPA'), ('er', 'PAfPA'), ('made', 'PAfPA'), ('out', 'PAfPA'), ('of', 'PAfPA'), ('tomatoes', 'PAfPA'), ('erm', 'PAfPA'), ('cucumbers', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('erm', 'PAfPA'), ('_0', 'PAfPA'), ('onion', 'PAfPA'), ('_0', 'PAfPA'), ('cheese', 'PAfPA'), ('_0', 'PAfPA')]
# [('aha', 'PAfPA'), ('we', 'PAfPA'), ('have', 'PAfPA'), ('that', 'PAfPA')]
# [('no', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('good', 'PAfPA'), ('it', 'PAfPA'), ('must', 'PAfPA'), ('be', 'PAfPA'), ('good', 'PAfPA')]
# [('yes', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('very', 'PAfPA'), ('good', 'PAfPA'), ('and', 'PAfPA'), ('er', 'PAfPA'), ('you', 'PAfPA'), ('you', 'PAfPA'), ('eat', 'PAfPA'), ('salad', 'PAfPA'), ('and', 'PAfPA'), ('or', 'PAfPA'), ('then', 'PAfPA'), ('or', 'PAfPA'), ('you', 'PAfPA'), ('_0', 'PAfPA'), ('you', 'PAfPA'), ('also', 'PAfPA'), ('have', 'PAfPA'), ('some', 'PAfPA'), ('like', 'PAfPA'), ('erm', 'PAfPA'), ('_2', 'PAfPA'), ('f_com', 'PAfPA'), ('f_commo', 'PAfPA'), ('f_se', 'PAfPA'), ('f_pronunce', 'PAfPA'), ('f_accetato', 'PAfPA')]
# [('f_com', 'PAfPA'), ('f_affectato', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_a-', 'PAfPA'), ('f_af-', 'PAfPA'), ('f_affetato', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_affetata', 'PAfPA')]
# [('that', 'PAfPA'), ("'s", 'PAfPA'), ('italian', 'PAfPA'), ('@', 'PAfPA'), ('does', 'PAfPA'), ("n't", 'PAfPA'), ('matter', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA')]
# [('ah', 'PAfPA'), ('feta', 'PAfPA'), ('f_xxx', 'PAfPA'), ('feta', 'PAfPA')]
# [('n-n', 'PAfPA'), ('no', 'PAfPA')]
# [('feta', 'PAfPA'), ('cheese', 'PAfPA'), ('you', 'PAfPA'), ('mean', 'PAfPA')]
# [('no', 'PAfPA'), ('no', 'PAfPA'), ('this', 'PAfPA'), ('like', 'PAfPA'), ('er', 'PAfPA'), ('er', 'PAfPA'), ('er', 'PAfPA'), ('salamis', 'PAfPA'), ('different', 'PAfPA'), ('types', 'PAfPA'), ('of', 'PAfPA'), ('salamis', 'PAfPA')]
# [('oh', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA')]
# [('okay', 'PAfPA'), ('er', 'PAfPA'), ('yeah', 'PAfPA')]
# [('er', 'PAfPA'), ('yellow', 'PAfPA'), ('cheese', 'PAfPA'), ('er', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA'), ('yeah', 'PAfPA'), ('the', 'PAfPA'), ('hard', 'PAfPA'), ('one', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('f_kashkaval', 'PAfPA')]
# [('f_kashkawa', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('yeah', 'PAfPA'), ('f_kashkawa', 'PAfPA'), ('_0', 'PAfPA'), ('f_kashkawa', 'PAfPA')]
# [('no', 'PAfPA')]
# [('no', 'PAfPA'), ('_0', 'PAfPA')]
# [('they', 'PAfPA'), ("'ll", 'PAfPA'), ('_1', 'PAfPA')]
# [('we', 'PAfPA'), ('got', 'PAfPA'), ('normal', 'PAfPA'), ('cheese', 'PAfPA')]
# [('you', 'PAfPA'), ('you', 'PAfPA'), ('call', 'PAfPA'), ('it', 'PAfPA'), ('different', 'PAfPA'), ('thing', 'PAfPA')]
# [('\n\nlike\n\n', 'PAfPA'), ('\nlike\n', 'PAfPA'), ('like', 'PAfPA'), ('some', 'PAfPA'), ('sort', 'PAfPA'), ('of', 'PAfPA'), ('mozzarella', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('something', 'PAfPA'), ('like', 'PAfPA'), ('mozzarella', 'PAfPA'), ('but', 'PAfPA'), ('which', 'PAfPA'), ('is', 'PAfPA'), ('like', 'PAfPA'), ('much', 'PAfPA'), ('more', 'PAfPA'), ('consistent', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_1', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA'), ('fat', 'PAfPA'), ('_2', 'PAfPA')]
# [('is', 'PAfPA'), ('this', 'PAfPA'), ('feta', 'PAfPA')]
# [('yeah', 'PAfPA'), ('mozzarella', 'PAfPA'), ('is', 'PAfPA'), ('er', 'PAfPA'), ('no', 'PAfPA'), ('_0', 'PAfPA'), ('because', 'PAfPA'), ('mozzarella', 'PAfPA'), ('is', 'PAfPA'), ('different', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_kashkaval', 'PAfPA'), ('is', 'PAfPA'), ('fat', 'PAfPA')]
# [('f_kashkaval', 'PAfPA'), ('is', 'PAfPA'), ('fat', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('fat', 'PAfPA'), ('but', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('feta', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('totally', 'PAfPA'), ('different', 'PAfPA'), ('thing', 'PAfPA')]
# [('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('and', 'PAfPA'), ('then', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('er', 'PAfPA'), ('how', 'PAfPA'), ('to', 'PAfPA'), ('say', 'PAfPA'), ('it', 'PAfPA'), ('does', 'PAfPA'), ("n't", 'PAfPA'), ('take', 'PAfPA'), ('you', 'PAfPA'), ('so', 'PAfPA'), ('er', 'PAfPA'), ('so', 'PAfPA'), ('quickly', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('yeah', 'PAfPA'), ('because', 'PAfPA'), ('you', 'PAfPA'), ('ate', 'PAfPA'), ('but', 'PAfPA'), ('last', 'PAfPA'), ('year', 'PAfPA'), ('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('@@', 'PAfPA'), ('and', 'PAfPA')]
# [('because', 'PAfPA'), ('if', 'PAfPA'), ('you', 'PAfPA')]
# [('if', 'PAfPA'), ('you', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('eat', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('er', 'PAfPA'), ('really', 'PAfPA'), ('_0', 'PAfPA')]
# [('hh', 'PAfPA'), ('my', 'PAfPA'), ('head', 'PAfPA'), ('hurts', 'PAfPA')]
# [('here', 'PAfPA'), ('_0', 'PAfPA')]
# [('my', 'PAfPA'), ('my', 'PAfPA'), ('nose', 'PAfPA'), ('hurts', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA'), ('why', 'PAfPA')]
# [('you', 'PAfPA'), ('know', 'PAfPA'), ('why', 'PAfPA'), ('because', 'PAfPA'), ('i', 'PAfPA'), ('wan-', 'PAfPA'), ('i', 'PAfPA'), ('wanted', 'PAfPA'), ('to', 'PAfPA'), ('have', 'PAfPA'), ('a', 'PAfPA'), ('shower', 'PAfPA'), ('and', 'PAfPA'), ('my', 'PAfPA'), ('er', 'PAfPA'), ('my', 'PAfPA'), ('bar', 'PAfPA'), ('of', 'PAfPA'), ('soap', 'PAfPA'), ('dropped', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('@@@', 'PAfPA'), ('@@', 'PAfPA')]
# [('tube', 'PAfPA'), ('_0', 'PAfPA'), ('and', 'PAfPA'), ('when', 'PAfPA'), ('i', 'PAfPA'), ('got', 'PAfPA'), ('up', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('got', 'PAfPA'), ('up', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('hit', 'PAfPA'), ('myself', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA')]
# [('@@@', 'PAfPA'), ('_0', 'PAfPA'), ('@@', 'PAfPA')]
# [('erm', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('like', 'PAfPA'), ('o_bvuff', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('you', 'PAfPA'), ('know', 'PAfPA'), ('_0', 'PAfPA')]
# [('being', 'PAfPA'), ('in', 'PAfPA'), ('poland', 'PAfPA'), ('in', 'PAfPA'), ('prison', 'PAfPA'), ('_1', 'PAfPA'), ('when', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('you', 'PAfPA'), ("'re", 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('in', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('what', 'PAfPA'), ('when', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('in', 'PAfPA'), ('prison', 'PAfPA'), ('in', 'PAfPA'), ('poland', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('what', 'PAfPA'), ('no', 'PAfPA'), ('@', 'PAfPA'), ('ah', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('talking', 'PAfPA'), ('because', 'PAfPA'), ('erm', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('doing', 'PAfPA'), ('the', 'PAfPA'), ('legal', 'PAfPA'), ('erm', 'PAfPA'), ('legal', 'PAfPA'), ('clinic', 'PAfPA'), ('course', 'PAfPA'), ('_0', 'PAfPA'), ('like', 'PAfPA'), ('we', 'PAfPA'), ("'re", 'PAfPA'), ('advising', 'PAfPA'), ('for', 'PAfPA'), ('poor', 'PAfPA'), ('people', 'PAfPA'), ('so', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA')]
# [('some', 'PAfPA'), ('of', 'PAfPA'), ('them', 'PAfPA'), ('were', 'PAfPA'), ('criminals', 'PAfPA'), ('because', 'PAfPA'), ('they', 'PAfPA'), ('could', 'PAfPA'), ("n't", 'PAfPA'), ('afford', 'PAfPA'), ('their', 'PAfPA'), ('lawyer', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('so', 'PAfPA'), ('_0', 'PAfPA'), ('they', 'PAfPA'), ('were', 'PAfPA'), ('talking', 'PAfPA'), ('really', 'PAfPA'), ('weird', 'PAfPA'), ('stories', 'PAfPA'), ('and', 'PAfPA'), ('_0', 'PAfPA'), ('er', 'PAfPA'), ('they', 'PAfPA'), ('said', 'PAfPA'), ('that', 'PAfPA'), ('_0', 'PAfPA'), ('if', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('standing', 'PAfPA'), ('in', 'PAfPA'), ('the', 'PAfPA'), ('shower', 'PAfPA'), ('_0', 'PAfPA'), ('and', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('like', 'PAfPA'), ('the', 'PAfPA'), ('freshman', 'PAfPA'), ('in', 'PAfPA'), ('prison', 'PAfPA'), ('they', 'PAfPA'), ("'re", 'PAfPA'), ('_1', 'PAfPA')]
# [('oh', 'PAfPA'), ('my', 'PAfPA'), ('gosh', 'PAfPA')]
# [('they', 'PAfPA'), ("'re", 'PAfPA'), ('taking', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('soap', 'PAfPA'), ('and', 'PAfPA'), ('they', 'PAfPA'), ("'re", 'PAfPA'), ('putting', 'PAfPA'), ('it', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('floor', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('and', 'PAfPA'), ('the', 'PAfPA'), ('soap', 'PAfPA'), ('yes', 'PAfPA')]
# [('deliberately', 'PAfPA'), ('@@@', 'PAfPA'), ('@@@', 'PAfPA'), ('@@@', 'PAfPA'), ('@@@', 'PAfPA')]
# [('oh', 'PAfPA'), ('my', 'PAfPA'), ('god', 'PAfPA')]
# [('ah', 'PAfPA'), ('well', 'PAfPA'), ('yes', 'PAfPA'), ('_1', 'PAfPA')]
# [('@@@@', 'PAfPA')]
# [('well', 'PAfPA'), ('@@', 'PAfPA')]
# [('ah', 'PAfPA')]
# [('f_nicht', 'PAfPA'), ('f_gut', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_nicht', 'PAfPA'), ('f_gut', 'PAfPA'), ('@@', 'PAfPA')]
# [('yeah', 'PAfPA'), ('f_nicht', 'PAfPA'), ('f_gut', 'PAfPA'), ('@', 'PAfPA')]
# [('bad', 'PAfPA')]
# [('yeah', 'PAfPA'), ('and', 'PAfPA'), ('did', 'PAfPA'), ('i', 'PAfPA'), ('tell', 'PAfPA'), ('you', 'PAfPA'), ('the', 'PAfPA'), ('story', 'PAfPA'), ('erm', 'PAfPA')]
# [('f_xxxxxx', 'PAfPA')]
# [('okay', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('going', 'PAfPA'), ('to', 'PAfPA'), ('_0', 'PAfPA'), ('to', 'PAfPA'), ('read', 'PAfPA'), ('a', 'PAfPA'), ('bit', 'PAfPA'), ('probably', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('are', 'PAfPA'), ('you', 'PAfPA'), ('staying', 'PAfPA'), ('for', 'PAfPA'), ('lunch', 'PAfPA'), ('or', 'PAfPA')]
# [('i', 'PAfPA'), ('have', 'PAfPA'), ('a', 'PAfPA'), ('presentation', 'PAfPA'), ('no', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('have', 'PAfPA'), ('a', 'PAfPA'), ('presentation', 'PAfPA'), ('in', 'PAfPA'), ('german', 'PAfPA'), ('@@', 'PAfPA')]
# [('okay', 'PAfPA')]
# [('oh', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('i', 'PAfPA'), ("'ve", 'PAfPA'), ('already', 'PAfPA'), ('done', 'PAfPA'), ('that', 'PAfPA')]
# [('good', 'PAfPA'), ('luck', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('have', 'PAfPA'), ('it', 'PAfPA'), ('tomorrow', 'PAfPA')]
# [('i', 'PAfPA'), ("'ve", 'PAfPA'), ('got', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('got', 'PAfPA'), ('like', 'PAfPA'), ('a', 'PAfPA'), ('pictures', 'PAfPA'), ('from', 'PAfPA'), ('the', 'PAfPA'), ('internet', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('well', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('nice', 'PAfPA')]
# [('yeah', 'PAfPA'), ('them', 'PAfPA'), ('okay', 'PAfPA'), ('they', 'PAfPA'), ("'re", 'PAfPA'), ('xx', 'PAfPA'), ('the', 'PAfPA'), ('pictures', 'PAfPA')]
# [('i', 'PAfPA'), ("'m", 'PAfPA'), ('doing', 'PAfPA')]
# [('what', 'PAfPA'), ('are', 'PAfPA'), ('you', 'PAfPA'), ('doing', 'PAfPA'), ('on', 'PAfPA'), ('_0', 'PAfPA')]
# [('haeh', 'PAfPA'), ('_0', 'PAfPA')]
# [('what', 'PAfPA'), ('are', 'PAfPA'), ('you', 'PAfPA'), ('doing', 'PAfPA'), ('your', 'PAfPA'), ('presentation', 'PAfPA')]
# [('my', 'PAfPA'), ('hometown', 'PAfPA'), ('@@@', 'PAfPA')]
# [('ok-', 'PAfPA'), ('i', 'PAfPA'), ('am', 'PAfPA'), ('doing', 'PAfPA'), ('it', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('festival', 'PAfPA'), ('of', 'PAfPA'), ('f_sighisora', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('ah', 'PAfPA'), ('nice', 'PAfPA')]
# [('i', 'PAfPA'), ('guess', 'PAfPA'), ('i', 'PAfPA'), ('have', 'PAfPA'), ('the', 'PAfPA'), ('weirdest', 'PAfPA'), ('one', 'PAfPA'), ('because', 'PAfPA')]
# [('i', 'PAfPA'), ("'ll", 'PAfPA'), ('come', 'PAfPA'), ('to', 'PAfPA'), ('listen', 'PAfPA')]
# [('@@@@', 'PAfPA')]
# [('@', 'PAfPA')]
# [('have', 'PAfPA'), ('you', 'PAfPA'), ('ever', 'PAfPA'), ('been', 'PAfPA'), ('_0', 'PAfPA'), ('to', 'PAfPA'), ('f_sighisora', 'PAfPA'), ('fest', 'PAfPA')]
# [('no', 'PAfPA'), ('_0', 'PAfPA'), ('ah', 'PAfPA'), ('yeah', 'PAfPA'), ('ac-', 'PAfPA'), ('actually', 'PAfPA'), ('i', 'PAfPA'), ('have', 'PAfPA'), ("n't", 'PAfPA'), ('been', 'PAfPA'), ('to', 'PAfPA'), ('the', 'PAfPA'), ('festival', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ("'ve", 'PAfPA'), ('been', 'PAfPA'), ('to', 'PAfPA'), ('f_sighisora', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('very', 'PAfPA'), ('beautiful', 'PAfPA'), ('_0', 'PAfPA')]
# [('so', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('beautiful', 'PAfPA'), ('_2', 'PAfPA')]
# [('okay', 'PAfPA')]
# [('there', 'PAfPA'), ('are', 'PAfPA'), ('lots', 'PAfPA'), ('of', 'PAfPA'), ('beautiful', 'PAfPA'), ('places', 'PAfPA'), ('in', 'PAfPA'), ('romania', 'PAfPA'), ('_0', 'PAfPA')]
# [('then', 'PAfPA'), ('come', 'PAfPA'), ('to', 'PAfPA'), ('romania', 'PAfPA')]
# [('@@', 'PAfPA'), ('@@@', 'PAfPA'), ('@@@', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('but', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('not', 'PAfPA'), ('from', 'PAfPA'), ('romania', 'PAfPA'), ('@', 'PAfPA')]
# [('oh', 'PAfPA'), ('no', 'PAfPA'), ('not', 'PAfPA'), ('ever', 'PAfPA'), ('@', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@', 'PAfPA')]
# [('and', 'PAfPA'), ('if', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('from', 'PAfPA'), ('romania', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('not', 'PAfPA'), ('the', 'PAfPA'), ('guy', 'PAfPA'), ('from', 'PAfPA'), ('romania', 'PAfPA'), ('i', 'PAfPA'), ('am', 'PAfPA'), ('the', 'PAfPA'), ('girl', 'PAfPA'), ('@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('_1', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('very', 'PAfPA'), ('obvious', 'PAfPA'), ('just', 'PAfPA'), ('listening', 'PAfPA'), ('to', 'PAfPA'), ('you', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('how', 'PAfPA'), ('do', 'PAfPA'), ('you', 'PAfPA'), ('say', 'PAfPA'), ('muns-', 'PAfPA'), ('mus-', 'PAfPA'), ('mu-', 'PAfPA'), ('mustard', 'PAfPA'), ('_1', 'PAfPA')]
# [('what', 'PAfPA'), ('_0', 'PAfPA')]
# [('mustard', 'PAfPA'), ('_1', 'PAfPA')]
# [('in', 'PAfPA'), ('polish', 'PAfPA')]
# [('no', 'PAfPA'), ('in', 'PAfPA'), ('german', 'PAfPA'), ('_1', 'PAfPA')]
# [('f_senf', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('f_senf', 'PAfPA'), ('okay', 'PAfPA'), ('_1', 'PAfPA'), ('er', 'PAfPA'), ('f_groestkartoffeln', 'PAfPA'), ('f_mit', 'PAfPA'), ('f_fleisch', 'PAfPA'), ('_0', 'PAfPA'), ('f_gebroten', 'PAfPA'), ('_1', 'PAfPA')]
# [('f_gebraten', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_gebraten', 'PAfPA'), ('whatever', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA')]
# [('f_sau-', 'PAfPA'), ('f_sau-', 'PAfPA'), ('f_sauerk-', 'PAfPA'), ('i', 'PAfPA'), ('was', 'PAfPA'), ('going', 'PAfPA'), ('to', 'PAfPA'), ('say', 'PAfPA'), ('f_sauberkraut', 'PAfPA'), ('@@', 'PAfPA')]
# [('@@@@', 'PAfPA'), ('no', 'PAfPA'), ('f_sauerkraut', 'PAfPA'), ('is', 'PAfPA'), ('cabbage', 'PAfPA')]
# [('f_sauer-', 'PAfPA'), ('yeah', 'PAfPA'), ('yeah', 'PAfPA'), ('cabbage', 'PAfPA'), ('_0', 'PAfPA')]
# [('erm', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('know', 'PAfPA'), ('the', 'PAfPA'), ('name', 'PAfPA')]
# [('f_wiener', 'PAfPA'), ('f_schnitzel', 'PAfPA'), ('er', 'PAfPA')]
# [('what', 'PAfPA'), ("'s", 'PAfPA'), ('the', 'PAfPA'), ('name', 'PAfPA'), ('for', 'PAfPA'), ('this', 'PAfPA'), ('f_gebratene', 'PAfPA'), ('stuff', 'PAfPA'), ('_1', 'PAfPA')]
# [('grilled', 'PAfPA'), ('_1', 'PAfPA')]
# [('f_gebratene', 'PAfPA'), ('not', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('grilled', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('f_gebraten', 'PAfPA'), ('_0', 'PAfPA')]
# [('fried', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_1', 'PAfPA')]
# [('fried', 'PAfPA'), ('_1', 'PAfPA'), ('f_groest', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('f_groest', 'PAfPA'), ('is', 'PAfPA'), ('it', 'PAfPA')]
# [('hm', 'PAfPA'), ('f_groest', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_groest', 'PAfPA'), ('_0', 'PAfPA'), ('mhm', 'PAfPA')]
# [('f_sachertorte', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_sachertorte', 'PAfPA'), ('oh', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('so', 'PAfPA'), ('disgusting', 'PAfPA')]
# [('yeah', 'PAfPA'), ('@@@', 'PAfPA'), ('f_sachertorte', 'PAfPA'), ('f_bratwurst', 'PAfPA'), ('f_und', 'PAfPA'), ('f_weisswurst', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('that', 'PAfPA'), ('is', 'PAfPA'), ('a', 'PAfPA'), ('german', 'PAfPA'), ('_0', 'PAfPA'), ('f_weisswurst', 'PAfPA'), ('is', 'PAfPA'), ('more', 'PAfPA'), ('german', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('f_leberknoedel', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('shit', 'PAfPA'), ('they', 'PAfPA'), ('gave', 'PAfPA'), ('us', 'PAfPA'), ('@', 'PAfPA')]
# [('@@@', 'PAfPA'), ('yes', 'PAfPA'), ('f_leberkaese', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('like', 'PAfPA'), ('f_leberknoedel', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('yeah', 'PAfPA')]
# [('f_leberkaese', 'PAfPA')]
# [('f_leberknoedel', 'PAfPA'), ('_1', 'PAfPA'), ('or', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('this', 'PAfPA'), ('bun', 'PAfPA'), ('er', 'PAfPA'), ('f_broetchen', 'PAfPA'), ('_0', 'PAfPA'), ('f_er', 'PAfPA'), ('f_de-', 'PAfPA'), ('f_die', 'PAfPA'), ('f_semmel', 'PAfPA'), ('f_und', 'PAfPA'), ('f_die', 'PAfPA'), ('f_broetchen', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('the', 'PAfPA'), ('f_broetchen', 'PAfPA'), ('is', 'PAfPA'), ('er', 'PAfPA'), ('the', 'PAfPA')]
# [('the', 'PAfPA'), ('whole', 'PAfPA'), ('bread', 'PAfPA')]
# [('the', 'PAfPA'), ('roll', 'PAfPA'), ('_0', 'PAfPA'), ('the', 'PAfPA'), ('small', 'PAfPA'), ('the', 'PAfPA'), ('roll', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('er', 'PAfPA'), ('in', 'PAfPA'), ('german', 'PAfPA'), ('and', 'PAfPA'), ('f_semmel', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('austrian', 'PAfPA'), ('_1', 'PAfPA'), ('word', 'PAfPA'), ('for', 'PAfPA'), ('the', 'PAfPA'), ('same', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('f_die', 'PAfPA'), ('f_semmel', 'PAfPA'), ('is', 'PAfPA'), ('austrian', 'PAfPA')]
# [('okay', 'PAfPA'), ('f_gulasch', 'PAfPA'), ('that', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA')]
# [('f_gulasch', 'PAfPA'), ('is', 'PAfPA'), ('goulash', 'PAfPA')]
# [('f_apfelstrudel', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_apfelstrudel', 'PAfPA'), ('is', 'PAfPA'), ('quite', 'PAfPA'), ('good', 'PAfPA')]
# [('this', 'PAfPA'), ('is', 'PAfPA')]
# [('this', 'PAfPA'), ('is', 'PAfPA'), ('yeah', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('have', 'PAfPA'), ('it', 'PAfPA'), ('in', 'PAfPA'), ('romania', 'PAfPA'), ('_0', 'PAfPA'), ('f_rote', 'PAfPA'), ('f_gruetze', 'PAfPA'), ('the', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('shitty', 'PAfPA'), ('purée', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('okay', 'PAfPA'), ('_0', 'PAfPA'), ('f_bretzel', 'PAfPA'), ('is', 'PAfPA'), ('like', 'PAfPA'), ('f_bretzel', 'PAfPA'), ('is', 'PAfPA'), ('like', 'PAfPA'), ('in', 'PAfPA'), ('english', 'PAfPA')]
# [('pretzel', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('s_p', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('\n\nlike\n\n', 'PAfPA'), ('\nlike\n', 'PAfPA'), ('like', 'PAfPA'), ('in', 'PAfPA'), ('_0', 'PAfPA')]
# [('s_p', 'PAfPA'), ('_0', 'PAfPA')]
# [('s_p', 'PAfPA'), ('_0', 'PAfPA')]
# [('s_p', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('s_p', 'PAfPA')]
# [('s_p', 'PAfPA'), ('_0', 'PAfPA')]
# [('pretzel', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA'), ('with', 'PAfPA'), ('a', 'PAfPA'), ('s_p', 'PAfPA'), ('_0', 'PAfPA')]
# [('p-', 'PAfPA'), ('_0', 'PAfPA'), ('s_p', 'PAfPA')]
# [('p-', 'PAfPA'), ('_0', 'PAfPA'), ('like', 'PAfPA')]
# [('s_p', 'PAfPA'), ('_0', 'PAfPA'), ('poland', 'PAfPA')]
# [('poland', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@@', 'PAfPA'), ('_0', 'PAfPA'), ('but', 'PAfPA'), ('you', 'PAfPA'), ('are', 'PAfPA'), ('not', 'PAfPA'), ('from', 'PAfPA'), ('poland', 'PAfPA'), ('_1', 'PAfPA')]
# [('@', 'PAfPA'), ('_1', 'PAfPA'), ('okay', 'PAfPA'), ('_0', 'PAfPA')]
# [('pretzel', 'PAfPA'), ('do', 'PAfPA'), ('you', 'PAfPA'), ('know', 'PAfPA'), ('pretzels', 'PAfPA')]
# [('s_p', 'PAfPA'), ('_2', 'PAfPA')]
# [('no', 'PAfPA'), ('do', 'PAfPA'), ('you', 'PAfPA'), ('know', 'PAfPA'), ('pretzels', 'PAfPA'), ('w-', 'PAfPA'), ('what', 'PAfPA'), ('does', 'PAfPA'), ('pretel-', 'PAfPA'), ('pretzel', 'PAfPA'), ('mean', 'PAfPA')]
# [('okay', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('not', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('hard', 'PAfPA'), ('erm', 'PAfPA'), ('_2', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('something', 'PAfPA'), ('like', 'PAfPA'), ('that', 'PAfPA'), ('_7', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('made', 'PAfPA'), ('of', 'PAfPA'), ('erm', 'PAfPA'), ('bro-', 'PAfPA'), ('_0', 'PAfPA'), ('bread', 'PAfPA')]
# [('bread', 'PAfPA'), ('yeah', 'PAfPA'), ('yeah', 'PAfPA'), ('f_bretzel', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('f_bretzel', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('salty', 'PAfPA')]
# [('pretzel', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('yeah', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('pretzel', 'PAfPA'), ('_0', 'PAfPA')]
# [('but', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('with', 'PAfPA'), ('a', 'PAfPA'), ('s_b', 'PAfPA'), ('not', 'PAfPA'), ('a', 'PAfPA'), ('s_p', 'PAfPA'), ('_1', 'PAfPA')]
# [('er', 'PAfPA'), ('we', 'PAfPA'), ('we', 'PAfPA'), ('have', 'PAfPA'), ('it', 'PAfPA'), ('with', 'PAfPA'), ('poppy', 'PAfPA'), ('seed', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_bretzel', 'PAfPA')]
# [('and', 'PAfPA'), ('with', 'PAfPA'), ('salt', 'PAfPA')]
# [('yeah', 'PAfPA'), ('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('and', 'PAfPA'), ('with', 'PAfPA'), ('sesame', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('wit-', 'PAfPA')]
# [('xx', 'PAfPA'), ('yeah', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('f_bretzel', 'PAfPA'), ('not', 'PAfPA'), ('pretzel', 'PAfPA')]
# [('uhu', 'PAfPA')]
# [('with', 'PAfPA'), ('a', 'PAfPA'), ('s_b', 'PAfPA'), ('_0', 'PAfPA')]
# [('we', 'PAfPA'), ('call', 'PAfPA'), ('it', 'PAfPA'), ('pretzel', 'PAfPA')]
# [('like', 'PAfPA'), ('bulgaria', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA'), ('_0', 'PAfPA'), ('pretzel', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('are', 'PAfPA'), ('from', 'PAfPA'), ('bulgaria', 'PAfPA'), ('@@@@@@@', 'PAfPA')]
# [('f_bretzel', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_2', 'PAfPA'), ('f_bretzel', 'PAfPA'), ('_0', 'PAfPA')]
# [('pretzel', 'PAfPA')]
# [('and', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('f_bretzel', 'PAfPA'), ('f_ausbeutung', 'PAfPA'), ('_1', 'PAfPA'), ('f_ausbeutung', 'PAfPA')]
# [('what', 'PAfPA'), ('is', 'PAfPA'), ('f_ausbeutung', 'PAfPA')]
# [('f_die', 'PAfPA'), ('f_ausbeutung', 'PAfPA')]
# [('f_ausbeutung', 'PAfPA')]
# [('exploita-', 'PAfPA'), ('exploitation', 'PAfPA'), ('exploi-', 'PAfPA'), ('exploitation', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_aus-', 'PAfPA'), ('what', 'PAfPA')]
# [('f_ausbeutung', 'PAfPA'), ('bef-', 'PAfPA'), ('f_ausbeutung', 'PAfPA'), ('yeah', 'PAfPA'), ('you', 'PAfPA'), ('wrote', 'PAfPA'), ('it', 'PAfPA'), ('_1', 'PAfPA')]
# [('really', 'PAfPA'), ('did', 'PAfPA'), ('i', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('there', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('first', 'PAfPA'), ('one', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_ausbeutung', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('right', 'PAfPA')]
# [('f_ausbeutung', 'PAfPA')]
# [('the', 'PAfPA'), ('exploitation', 'PAfPA')]
# [('f_befoerdern', 'PAfPA'), ('er', 'PAfPA'), ('trans-', 'PAfPA')]
# [('f_befoerderung', 'PAfPA')]
# [('that', 'PAfPA'), ("'s", 'PAfPA'), ('er', 'PAfPA'), ('tra-', 'PAfPA'), ('pro-', 'PAfPA'), ('bre-', 'PAfPA'), ('f_befoerderung', 'PAfPA'), ('transportation', 'PAfPA'), ('hh', 'PAfPA'), ('f_weltraumstation', 'PAfPA'), ('f_-station', 'PAfPA'), ('_0', 'PAfPA')]
# [('to', 'PAfPA'), ('transport', 'PAfPA')]
# [('that', 'PAfPA'), ("'s", 'PAfPA')]
# [('yeah', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('like', 'PAfPA'), ('they', 'PAfPA'), ('are', 'PAfPA'), ('very', 'PAfPA'), ('famous', 'PAfPA'), ('because', 'PAfPA'), ('she', 'PAfPA'), ('was', 'PAfPA'), ('talking', 'PAfPA'), ('about', 'PAfPA'), ('her', 'PAfPA'), ('country', 'PAfPA'), ('_0', 'PAfPA')]
# [('funny', 'PAfPA')]
# ...
# [('no', 'PAfPA'), ('we', 'PAfPA'), ("'re", 'PAfPA'), ('not', 'PAfPA'), ('_2', 'PAfPA'), ('i', 'PAfPA'), ('am', 'PAfPA'), ('a', 'PAfPA'), ('lawyer', 'PAfPA')]
# [('ooph', 'PAfPA'), ('hhh', 'PAfPA'), ('_14', 'PAfPA')]
# [('so', 'PAfPA'), ('are', 'PAfPA'), ('most', 'PAfPA'), ('of', 'PAfPA'), ('the', 'PAfPA'), ('v-', 'PAfPA'), ('_0', 'PAfPA'), ('the', 'PAfPA'), ('verbs', 'PAfPA'), ('in', 'PAfPA'), ('german', 'PAfPA'), ('they', 'PAfPA'), ('need', 'PAfPA'), ('_1', 'PAfPA'), ('f_akkusativ', 'PAfPA'), ('right', 'PAfPA'), ('_1', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_0', 'PAfPA')]
# [('right', 'PAfPA'), ('there', 'PAfPA'), ('are', 'PAfPA'), ('some', 'PAfPA'), ('_0', 'PAfPA')]
# [('there', 'PAfPA'), ('are', 'PAfPA'), ('some', 'PAfPA'), ('stupid', 'PAfPA'), ('verbs', 'PAfPA'), ('that', 'PAfPA'), ('er', 'PAfPA'), ('_1', 'PAfPA'), ('go', 'PAfPA'), ('in', 'PAfPA'), ('f_akkusativ', 'PAfPA'), ('and', 'PAfPA'), ('or', 'PAfPA'), ('in', 'PAfPA'), ('_0', 'PAfPA'), ('or', 'PAfPA'), ('in', 'PAfPA'), ('in', 'PAfPA'), ('the', 'PAfPA'), ('da-', 'PAfPA'), ('or', 'PAfPA'), ('in', 'PAfPA'), ('f_dativ', 'PAfPA')]
# [('yeah', 'PAfPA')]
# [('aha', 'PAfPA')]
# [('depends', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('situation', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('f_wo', 'PAfPA'), ('and', 'PAfPA'), ('f_wohin', 'PAfPA'), ('and', 'PAfPA'), ('_1', 'PAfPA'), ('er', 'PAfPA'), ('we', 'PAfPA'), ("'ve", 'PAfPA'), ('got', 'PAfPA'), ('er', 'PAfPA'), ('like', 'PAfPA'), ('exceptions', 'PAfPA'), ('_0', 'PAfPA'), ('verbs', 'PAfPA'), ('with', 'PAfPA'), ('f_dativ', 'PAfPA'), ('_0', 'PAfPA'), ('only', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('say', 'PAfPA'), ('they', 'PAfPA'), ("'re", 'PAfPA'), ('exceptions', 'PAfPA'), ('like', 'PAfPA'), ('there', 'PAfPA'), ('are', 'PAfPA'), ('_0', 'PAfPA'), ('verbs', 'PAfPA'), ('that', 'PAfPA'), ('go', 'PAfPA'), ('with', 'PAfPA'), ('f_akkusativ', 'PAfPA'), ('and', 'PAfPA'), ('also', 'PAfPA'), ('the', 'PAfPA'), ('words', 'PAfPA'), ('that', 'PAfPA'), ('go', 'PAfPA'), ('with', 'PAfPA'), ('f_dativ', 'PAfPA')]
# [('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('which', 'PAfPA'), ('are', 'PAfPA'), ('\n\nless\n\n', 'PAfPA'), ('\nless\n', 'PAfPA'), ('less', 'PAfPA'), ('_2', 'PAfPA')]
# [('i', 'PAfPA'), ('know', 'PAfPA'), ('_2', 'PAfPA'), ('i', 'PAfPA'), ('know', 'PAfPA'), ('_41', 'PAfPA')]
# [('@@@', 'PAfPA'), ('silly', 'PAfPA'), ('people', 'PAfPA')]
# [('@@', 'PAfPA'), ('@@@', 'PAfPA'), ('_2', 'PAfPA')]
# [('@@', 'PAfPA'), ('_1', 'PAfPA')]
# [('okay', 'PAfPA'), ('_28', 'PAfPA'), ('do', 'PAfPA'), ('you', 'PAfPA'), ('know', 'PAfPA'), ('the', 'PAfPA'), ('expression', 'PAfPA'), ('off', 'PAfPA'), ('the', 'PAfPA'), ('record', 'PAfPA'), ('_2', 'PAfPA')]
# [('off', 'PAfPA'), ('the', 'PAfPA'), ('record', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@@', 'PAfPA'), ('_0', 'PAfPA')]
# [('@', 'PAfPA'), ('_4', 'PAfPA')]
# [('f_glauben', 'PAfPA'), ('f_gehoeren', 'PAfPA'), ('_23', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('pretty', 'PAfPA'), ('vain', 'PAfPA'), ('to', 'PAfPA'), ('_0', 'PAfPA'), ('read', 'PAfPA'), ('the', 'PAfPA'), ('mass', 'PAfPA'), ('of', 'PAfPA'), ('these', 'PAfPA'), ('_1', 'PAfPA')]
# [('haeh', 'PAfPA')]
# [('like', 'PAfPA'), ('all', 'PAfPA'), ('over', 'PAfPA'), ('again', 'PAfPA')]
# [('no', 'PAfPA'), ('no', 'PAfPA'), ('i', 'PAfPA'), ('am', 'PAfPA'), ('looking', 'PAfPA'), ('for', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('xxxx', 'PAfPA'), ('_16', 'PAfPA')]
# [('f_befehlen', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('to', 'PAfPA'), ('command', 'PAfPA'), ('to', 'PAfPA'), ('command', 'PAfPA'), ('right', 'PAfPA'), ('f_befehlen', 'PAfPA'), ('_0', 'PAfPA')]
# [('to', 'PAfPA'), ('command', 'PAfPA')]
# [('to', 'PAfPA'), ('order', 'PAfPA'), ('yeah', 'PAfPA')]
# [('f_befehlen', 'PAfPA'), ('to', 'PAfPA'), ('order', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_der', 'PAfPA'), ('f_zoellner', 'PAfPA'), ('_0', 'PAfPA'), ('f_befehlt', 'PAfPA'), ('_37', 'PAfPA'), ('f_befehl', 'PAfPA'), ('_1', 'PAfPA')]
# [('@@', 'PAfPA'), ('what', 'PAfPA'), ('_38', 'PAfPA')]
# [('what', 'PAfPA'), ("'s", 'PAfPA'), ('f_erwidern', 'PAfPA'), ('_0', 'PAfPA')]
# [('what', 'PAfPA')]
# [('f_erwidern', 'PAfPA'), ('_2', 'PAfPA'), ('f_erwidern', 'PAfPA')]
# [('to', 'PAfPA'), ('er', 'PAfPA'), ('_1', 'PAfPA'), ('reply', 'PAfPA'), ('but', 'PAfPA'), ('_1', 'PAfPA'), ('to', 'PAfPA'), ('rep-', 'PAfPA')]
# [('oh', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('the', 'PAfPA'), ('same', 'PAfPA'), ('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('but', 'PAfPA'), ('not', 'PAfPA'), ('to', 'PAfPA'), ('reply', 'PAfPA'), ('someone', 'PAfPA'), ('but', 'PAfPA'), ('to', 'PAfPA'), ('reply', 'PAfPA'), ('erm', 'PAfPA')]
# [('to', 'PAfPA'), ('some-', 'PAfPA')]
# [('sentence', 'PAfPA'), ('yeah', 'PAfPA'), ('to', 'PAfPA'), ('someone', 'PAfPA')]
# [('okay', 'PAfPA'), ('_1', 'PAfPA')]
# [('but', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('i', 'PAfPA'), ('want', 'PAfPA'), ('to', 'PAfPA'), ('ask', 'PAfPA'), ('him', 'PAfPA'), ('because', 'PAfPA'), ('i', 'PAfPA'), ('found', 'PAfPA'), ('it', 'PAfPA'), ('like', 'PAfPA'), ('if', 'PAfPA'), ('you', 'PAfPA'), ('use', 'PAfPA'), ('it', 'PAfPA'), ('with', 'PAfPA'), ('f_auf', 'PAfPA'), ('_0', 'PAfPA')]
# [('mhm', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('f_akkusativ', 'PAfPA')]
# [('yeah', 'PAfPA'), ('f_auf', 'PAfPA'), ('is', 'PAfPA'), ('the', 'PAfPA'), ('one', 'PAfPA'), ('with', 'PAfPA'), ('accusative', 'PAfPA'), ('_0', 'PAfPA')]
# [('so', 'PAfPA'), ('why', 'PAfPA'), ('did', 'PAfPA'), ('they', 'PAfPA'), ('_1', 'PAfPA'), ('because', 'PAfPA'), ('they', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('have', 'PAfPA'), ('it', 'PAfPA'), ('in', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA'), ('both', 'PAfPA'), ('both', 'PAfPA'), ('_30', 'PAfPA')]
# [('f_danke', 'PAfPA')]
# [('f_danke', 'PAfPA'), ('er', 'PAfPA'), ('okay', 'PAfPA')]
# [('yeah', 'PAfPA'), ('yeah', 'PAfPA')]
# [('thanks', 'PAfPA'), ('_3', 'PAfPA')]
# [('f_fehlen', 'PAfPA'), ('_0', 'PAfPA')]
# [('f_fehlen', 'PAfPA'), ('to', 'PAfPA'), ('miss', 'PAfPA'), ('_3', 'PAfPA'), ('can', 'PAfPA'), ('say', 'PAfPA'), ('f_vermissen', 'PAfPA'), ('_0', 'PAfPA')]
# [('haeh', 'PAfPA')]
# [('sa-', 'PAfPA'), ('you', 'PAfPA'), ('can', 'PAfPA'), ('say', 'PAfPA'), ('f_vermissen', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('_0', 'PAfPA'), ('okay', 'PAfPA'), ('yes', 'PAfPA'), ('_7', 'PAfPA')]
# [('my', 'PAfPA'), ('head', 'PAfPA'), ('hurts', 'PAfPA'), ('_3', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('wan', 'PAfPA'), ('na', 'PAfPA'), ('puke', 'PAfPA'), ('_0', 'PAfPA')]
# [('@', 'PAfPA'), ('what', 'PAfPA'), ('_1', 'PAfPA')]
# [('yeah', 'PAfPA'), ('i', 'PAfPA'), ('wan', 'PAfPA'), ('na', 'PAfPA'), ('puke', 'PAfPA'), ('a', 'PAfPA'), ('little', 'PAfPA'), ('bit', 'PAfPA'), ('but', 'PAfPA'), ('_0', 'PAfPA')]
# [('@@@', 'PAfPA')]
# [('@', 'PAfPA'), ('what', 'PAfPA'), ('_0', 'PAfPA')]
# [('oh', 'PAfPA'), ('my', 'PAfPA'), ('god', 'PAfPA')]
# [('what', 'PAfPA')]
# [('this', 'PAfPA'), ('conversation', 'PAfPA'), ('@@@', 'PAfPA'), ('_8', 'PAfPA')]
# [('that', 'PAfPA'), ('pill', 'PAfPA'), ('was', 'PAfPA'), ('not', 'PAfPA'), ('good', 'PAfPA')]
# [('@@@@', 'PAfPA')]
# [('was', 'PAfPA'), ('it', 'PAfPA'), ('a', 'PAfPA'), ('vomiting', 'PAfPA'), ('pill', 'PAfPA'), ('or', 'PAfPA')]
# [('no', 'PAfPA'), ('_0', 'PAfPA'), ('no', 'PAfPA'), ('_0', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('with', 'PAfPA'), ('caffeine', 'PAfPA'), ('and', 'PAfPA'), ('with', 'PAfPA'), ('xxx', 'PAfPA'), ('_2', 'PAfPA'), ('it', 'PAfPA'), ('makes', 'PAfPA'), ('your', 'PAfPA'), ('blood', 'PAfPA'), ('pressure', 'PAfPA'), ('higher', 'PAfPA'), ('_1', 'PAfPA')]
# [('not', 'PAfPA'), ('good', 'PAfPA'), ('_0', 'PAfPA'), ('f_nicht', 'PAfPA'), ('f_gut', 'PAfPA'), ('_0', 'PAfPA'), ('but', 'PAfPA')]
# [('but', 'PAfPA'), ('you', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('xxx', 'PAfPA'), ('_0', 'PAfPA'), ('well', 'PAfPA'), ('you', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('xx', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('your', 'PAfPA'), ('change', 'PAfPA'), ('_2', 'PAfPA')]
# [('@', 'PAfPA'), ('_2', 'PAfPA'), ('why', 'PAfPA')]
# [('cos', 'PAfPA'), ('you', 'PAfPA'), ('gave', 'PAfPA'), ('me', 'PAfPA'), ('_0', 'PAfPA'), ('one', 'PAfPA'), ('ninety', 'PAfPA')]
# [('hh', 'PAfPA')]
# [('and', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('one', 'PAfPA'), ('seventy', 'PAfPA'), ('one', 'PAfPA'), ('_0', 'PAfPA')]
# [('okay', 'PAfPA'), ('you', 'PAfPA'), ('have', 'PAfPA'), ('one', 'PAfPA'), ('@', 'PAfPA'), ('_0', 'PAfPA'), ('euro', 'PAfPA'), ('cent', 'PAfPA'), ('_0', 'PAfPA'), ('come', 'PAfPA'), ('on', 'PAfPA')]
# [('no', 'PAfPA')]
# [('oh', 'PAfPA'), ('my', 'PAfPA'), ('god', 'PAfPA')]
# [('@@', 'PAfPA'), ('no', 'PAfPA'), ('_2', 'PAfPA'), ('you', 'PAfPA'), ('started', 'PAfPA'), ('that', 'PAfPA'), ('_0', 'PAfPA'), ('_2', 'PAfPA')]
# [('f_gut', 'PAfPA'), ('_4', 'PAfPA'), ('@', 'PAfPA')]
# [('f_gefallen', 'PAfPA'), ('_1', 'PAfPA'), ('f_gefallen', 'PAfPA'), ('f_gehoeren', 'PAfPA'), ('_2', 'PAfPA'), ('f_gehorchen', 'PAfPA'), ('to', 'PAfPA'), ('obey', 'PAfPA'), ('_2', 'PAfPA'), ('f_gehorchen', 'PAfPA'), ('to', 'PAfPA'), ('obey', 'PAfPA'), ('_0', 'PAfPA'), ('is', 'PAfPA'), ('it', 'PAfPA'), ('time', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('it', 'PAfPA'), ('is', 'PAfPA'), ('_0', 'PAfPA'), ('twenty', 'PAfPA'), ('past', 'PAfPA'), ('_2', 'PAfPA'), ('but', 'PAfPA'), ('i', 'PAfPA'), ('have', 'PAfPA'), ('to', 'PAfPA'), ('i', 'PAfPA'), ('can', 'PAfPA'), ('not', 'PAfPA'), ('go', 'PAfPA'), ('with', 'PAfPA'), ('the', 'PAfPA'), ('bag', 'PAfPA'), ('in', 'PAfPA'), ('the', 'PAfPA'), ('soap', 'PAfPA'), ('_2', 'PAfPA')]
# [('yeah', 'PAfPA'), ('there', 'PAfPA'), ("'s", 'PAfPA'), ('a', 'PAfPA'), ('x', 'PAfPA'), ('_0', 'PAfPA')]
# [('is', 'PAfPA'), ('this', 'PAfPA'), ('a', 'PAfPA'), ('statement', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA'), ('_1', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('overreacting', 'PAfPA'), ('_2', 'PAfPA')]
# [('ah', 'PAfPA'), ('_1', 'PAfPA'), ('it', 'PAfPA'), ('means', 'PAfPA'), ('i', 'PAfPA'), ("'m", 'PAfPA'), ('clean', 'PAfPA'), ('_0', 'PAfPA'), ('that', 'PAfPA'), ('i', 'PAfPA'), ('wash', 'PAfPA'), ('my', 'PAfPA'), ('clothes', 'PAfPA'), ('and', 'PAfPA'), ('i', 'PAfPA'), ('wash', 'PAfPA'), ('myself', 'PAfPA'), ('also', 'PAfPA'), ('_0', 'PAfPA'), ('@', 'PAfPA'), ('_25', 'PAfPA')]
# [('i', 'PAfPA'), ('ca', 'PAfPA'), ("n't", 'PAfPA'), ('see', 'PAfPA'), ('him', 'PAfPA'), ('at', 'PAfPA'), ('town', 'PAfPA'), ('_2', 'PAfPA')]
# [('what', 'PAfPA'), ('_2', 'PAfPA'), ('you', 'PAfPA'), ("'re", 'PAfPA'), ('what', 'PAfPA'), ('_1', 'PAfPA')]
# [('a_[firstname8]', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('_10', 'PAfPA')]
# [('someone', 'PAfPA'), ('is', 'PAfPA'), ('oh', 'PAfPA'), ('a_[S6]', 'PAfPA'), ('is', 'PAfPA'), ('really', 'PAfPA'), ('good', 'PAfPA'), ('_0', 'PAfPA'), ('at', 'PAfPA'), ('imitating', 'PAfPA'), ('_0', 'PAfPA')]
# [('hm', 'PAfPA'), ('_0', 'PAfPA')]
# [('a_[S6]', 'PAfPA'), ('is', 'PAfPA'), ('really', 'PAfPA'), ('good', 'PAfPA'), ('_0', 'PAfPA'), ('at', 'PAfPA'), ('imitating', 'PAfPA'), ('her', 'PAfPA'), ('voice', 'PAfPA'), ('_0', 'PAfPA')]
# [('a_[S6]', 'PAfPA'), ('_11', 'PAfPA')]
# [('i', 'PAfPA'), ("'m", 'PAfPA'), ('going', 'PAfPA'), ('to', 'PAfPA'), ('the', 'PAfPA'), ('crazy', 'PAfPA'), ('world', 'PAfPA'), ('where', 'PAfPA'), ('the', 'PAfPA'), ('wh-', 'PAfPA'), ('where', 'PAfPA'), ('the', 'PAfPA'), ('weather', 'PAfPA'), ('xxx', 'PAfPA'), ('with', 'PAfPA'), ('the', 'PAfPA'), ('same', 'PAfPA'), ('people', 'PAfPA'), ('_0', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('nice', 'PAfPA'), ('_1', 'PAfPA')]
# [('is', 'PAfPA'), ('it', 'PAfPA'), ('_1', 'PAfPA')]
# [('it', 'PAfPA'), ("'s", 'PAfPA'), ('get', 'PAfPA'), ('come', 'PAfPA'), ('on', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('nicer', 'PAfPA'), ('than', 'PAfPA'), ('this', 'PAfPA'), ('morning', 'PAfPA'), ('_0', 'PAfPA')]
# [('yeah', 'PAfPA'), ('but', 'PAfPA'), ('still', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('freezing', 'PAfPA'), ('_37', 'PAfPA')]
# [('go', 'PAfPA'), ('upstairs', 'PAfPA'), ('to', 'PAfPA'), ('take', 'PAfPA'), ('this', 'PAfPA'), ('xx', 'PAfPA'), ('xx', 'PAfPA'), ('x', 'PAfPA'), ('_3', 'PAfPA'), ('what', 'PAfPA'), ('_1', 'PAfPA'), ('i', 'PAfPA'), ('take', 'PAfPA'), ('this', 'PAfPA'), ('to', 'PAfPA'), ('my', 'PAfPA'), ('room', 'PAfPA'), ('why', 'PAfPA')]
# [('i', 'PAfPA'), ('know', 'PAfPA'), ('no', 'PAfPA'), ('no', 'PAfPA'), ('_0', 'PAfPA')]
# [('why', 'PAfPA'), ('_3', 'PAfPA'), ('come', 'PAfPA'), ('on', 'PAfPA')]
# [('never', 'PAfPA'), ('_1', 'PAfPA')]
# [('okay', 'PAfPA'), ('come', 'PAfPA'), ('on', 'PAfPA'), ('_1', 'PAfPA')]
# [('@@@@', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('good', 'PAfPA'), ('that', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('are', 'PAfPA'), ('having', 'PAfPA'), ('classes', 'PAfPA'), ('at', 'PAfPA'), ('second', 'PAfPA'), ('third', 'PAfPA'), ('floor', 'PAfPA'), ('_0', 'PAfPA')]
# [('second', 'PAfPA'), ('floor', 'PAfPA')]
# [('second', 'PAfPA'), ('floor', 'PAfPA'), ('_1', 'PAfPA')]
# [('why', 'PAfPA'), ('_0', 'PAfPA')]
# [('cos', 'PAfPA'), ('i', 'PAfPA'), ('would', 'PAfPA'), ("n't", 'PAfPA'), ('be', 'PAfPA'), ('able', 'PAfPA'), ('to', 'PAfPA'), ('visit', 'PAfPA'), ('you', 'PAfPA'), ('xx', 'PAfPA'), ('_1', 'PAfPA'), ('but', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA'), ('good', 'PAfPA'), ('_2', 'PAfPA')]
# [('on', 'PAfPA'), ('the', 'PAfPA'), ('first', 'PAfPA'), ('floor', 'PAfPA'), ('_0', 'PAfPA')]
# [('yes', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('am', 'PAfPA'), ('having', 'PAfPA'), ('a_[lastname7]', 'PAfPA'), ('classes', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('first', 'PAfPA'), ('floor', 'PAfPA')]
# [('but', 'PAfPA'), ('it', 'PAfPA'), ("'s", 'PAfPA'), ('good', 'PAfPA'), ('that', 'PAfPA'), ('_0', 'PAfPA'), ('i', 'PAfPA'), ('do', 'PAfPA'), ("n't", 'PAfPA'), ('have', 'PAfPA'), ('_0', 'PAfPA'), ('classes', 'PAfPA'), ('there', 'PAfPA'), ('_1', 'PAfPA')]
# [('you', 'PAfPA'), ("'re", 'PAfPA'), ('xxxx', 'PAfPA'), ('_0', 'PAfPA')]
# [('i', 'PAfPA'), ('am', 'PAfPA'), ('not', 'PAfPA'), ('on', 'PAfPA'), ('even', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('list', 'PAfPA')]
# [('you', 'PAfPA'), ("'re", 'PAfPA'), ('not', 'PAfPA'), ('on', 'PAfPA'), ('the', 'PAfPA'), ('list', 'PAfPA')]
# [('yes', 'PAfPA'), ('_14', 'PAfPA')]
# [('we', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA')]
# [('thanks', 'PAfPA'), ('a', 'PAfPA'), ('lot', 'PAfPA'), ('_0', 'PAfPA')]
# [('we', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('talk', 'PAfPA'), ('a', 'PAfPA'), ('lot', 'PAfPA'), ('like', 'PAfPA'), ('constantly', 'PAfPA'), ('_0', 'PAfPA')]
# [('no', 'PAfPA'), ('no', 'PAfPA'), ('but', 'PAfPA'), ('it', 'PAfPA'), ('was', 'PAfPA'), ('very', 'PAfPA'), ('nice', 'PAfPA'), ('you', 'PAfPA'), ('let', 'PAfPA'), ('us', 'PAfPA'), ('do', 'PAfPA'), ('this', 'PAfPA'), ('_0', 'PAfPA'), ('thanks', 'PAfPA'), ('a', 'PAfPA'), ('lot', 'PAfPA'), ('_0', 'PAfPA'), ('is', 'PAfPA'), ('this', 'PAfPA')]
# [('i', 'PAfPA'), ('hope', 'PAfPA'), ('that', 'PAfPA'), ('we', 'PAfPA'), ('did', 'PAfPA'), ("n't", 'PAfPA'), ('tell', 'PAfPA'), ('_0', 'PAfPA'), ('like', 'PAfPA'), ('the', 'PAfPA'), ('wor-', 'PAfPA'), ('the', 'PAfPA'), ('the', 'PAfPA'), ('_0', 'PAfPA'), ('the', 'PAfPA'), ('names', 'PAfPA'), ('_0', 'PAfPA')]
# [('why', 'PAfPA'), ('we', 'PAfPA'), ('will', 'PAfPA'), ('erase', 'PAfPA'), ('all', 'PAfPA'), ('names', 'PAfPA')]
# [('oh', 'PAfPA'), ('good', 'PAfPA')]
# [('so', 'PAfPA'), ('what-', 'PAfPA'), ('whoever', 'PAfPA'), ('you', 'PAfPA'), ('talked', 'PAfPA'), ('about', 'PAfPA'), ('nobody', 'PAfPA'), ('will', 'PAfPA'), ('know', 'PAfPA')]
# [('okay', 'PAfPA'), ('but', 'PAfPA')]
# [('cos', 'PAfPA'), ('we', 'PAfPA'), ('ju-', 'PAfPA'), ('ju-', 'PAfPA'), ('just', 'PAfPA'), ('write', 'PAfPA'), ('name', 'PAfPA'), ('one', 'PAfPA'), ('name', 'PAfPA'), ('two', 'PAfPA'), ('and', 'PAfPA')]
# [('oh', 'PAfPA'), ('okay', 'PAfPA'), ('that', 'PAfPA'), ("'s", 'PAfPA')]
# [('so', 'PAfPA'), ('_0', 'PAfPA')]
# [('that', 'PAfPA'), ("'s", 'PAfPA'), ('very', 'PAfPA'), ('good', 'PAfPA')]
# [('no', 'PAfPA'), ('names', 'PAfPA'), ('whatsoever', 'PAfPA'), ('@@@', 'PAfPA')]
# [('f_danke', 'PAfPA')]
# [('@@@', 'PAfPA'), ('well', 'PAfPA'), ('_0', 'PAfPA'), ('we', 'PAfPA'), ('thank', 'PAfPA'), ('you', 'PAfPA'), ('@', 'PAfPA'), ('_2', 'PAfPA')]
